# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('https://raw.githubusercontent.com/dsrscientist/Dataset2/main/temperature.csv')
df
# Out:
#       station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# 0         1.0  30-06-2013          28.7          21.4    58.255688
# 1         2.0  30-06-2013          31.9          21.6    52.263397
# 2         3.0  30-06-2013          31.6          23.3    48.690479
# 3         4.0  30-06-2013          32.0          23.4    58.239788
# 4         5.0  30-06-2013          31.4          21.9    56.174095
# ...       ...         ...           ...           ...          ...
# 7747     23.0  30-08-2017          23.3          17.1    26.741310
# 7748     24.0  30-08-2017          23.3          17.7    24.040634
# 7749     25.0  30-08-2017          23.2          17.4    22.933014
# 7750      NaN         NaN          20.0          11.3    19.794666
# 7751      NaN         NaN          37.6          29.9    98.524734
#
#       LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  \
# 0       91.116364         28.074101         23.006936   6.818887   69.451805
# 1       90.604721         29.850689         24.035009   5.691890   51.937448
# 2       83.973587         30.091292         24.565633   6.138224   20.573050
# 3       96.483688         29.704629         23.326177   5.650050   65.727144
# 4       90.155128         29.113934         23.486480   5.735004  107.965535
# ...           ...               ...               ...        ...         ...
# 7747    78.869858         26.352081         18.775678   6.148918   72.058294
# 7748    77.294975         27.010193         18.733519   6.542819   47.241457
# 7749    77.243744         27.939516         18.522965   7.289264    9.090034
# 7750    58.936283         17.624954         14.272646   2.882580  -13.603212
# 7751   100.000153         38.542255         29.619342  21.857621  213.414006
#
#       ...  LDAPS_PPT2  LDAPS_PPT3  LDAPS_PPT4      lat      lon       DEM  \
# 0     ...    0.000000    0.000000    0.000000  37.6046  126.991  212.3350
# 1     ...    0.000000    0.000000    0.000000  37.6046  127.032   44.7624
# 2     ...    0.000000    0.000000    0.000000  37.5776  127.058   33.3068
# 3     ...    0.000000    0.000000    0.000000  37.6450  127.022   45.7160
# 4     ...    0.000000    0.000000    0.000000  37.5507  127.135   35.0380
# ...   ...         ...         ...         ...      ...      ...       ...
# 7747  ...    0.000000    0.000000    0.000000  37.5372  126.891   15.5876
# 7748  ...    0.000000    0.000000    0.000000  37.5237  126.909   17.2956
# 7749  ...    0.000000    0.000000    0.000000  37.5237  126.970   19.5844
# 7750  ...    0.000000    0.000000    0.000000  37.4562  126.826   12.3700
# 7751  ...   21.621661   15.841235   16.655469  37.6450  127.135  212.3350
#
#          Slope  Solar radiation  Next_Tmax  Next_Tmin
# 0     2.785000      5992.895996       29.1       21.2
# 1     0.514100      5869.312500       30.5       22.5
# 2     0.266100      5863.555664       31.1       23.9
# 3     2.534800      5856.964844       31.7       24.3
# 4     0.505500      5859.552246       31.2       22.5
# ...        ...              ...        ...        ...
# 7747  0.155400      4443.313965       28.3       18.1
# 7748  0.222300      4438.373535       28.6       18.8
# 7749  0.271300      4451.345215       27.8       17.4
# 7750  0.098475      4329.520508       17.4       11.3
# 7751  5.178230      5992.895996       38.9       29.8
#
# [7752 rows x 25 columns]

# %%
df.head()
# Out:
#    station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0      1.0  30-06-2013          28.7          21.4    58.255688    91.116364
# 1      2.0  30-06-2013          31.9          21.6    52.263397    90.604721
# 2      3.0  30-06-2013          31.6          23.3    48.690479    83.973587
# 3      4.0  30-06-2013          32.0          23.4    58.239788    96.483688
# 4      5.0  30-06-2013          31.4          21.9    56.174095    90.155128
#
#    LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  ...  LDAPS_PPT2  \
# 0         28.074101         23.006936  6.818887   69.451805  ...         0.0
# 1         29.850689         24.035009  5.691890   51.937448  ...         0.0
# 2         30.091292         24.565633  6.138224   20.573050  ...         0.0
# 3         29.704629         23.326177  5.650050   65.727144  ...         0.0
# 4         29.113934         23.486480  5.735004  107.965535  ...         0.0
#
#    LDAPS_PPT3  LDAPS_PPT4      lat      lon       DEM   Slope  \
# 0         0.0         0.0  37.6046  126.991  212.3350  2.7850
# 1         0.0         0.0  37.6046  127.032   44.7624  0.5141
# 2         0.0         0.0  37.5776  127.058   33.3068  0.2661
# 3         0.0         0.0  37.6450  127.022   45.7160  2.5348
# 4         0.0         0.0  37.5507  127.135   35.0380  0.5055
#
#    Solar radiation  Next_Tmax  Next_Tmin
# 0      5992.895996       29.1       21.2
# 1      5869.312500       30.5       22.5
# 2      5863.555664       31.1       23.9
# 3      5856.964844       31.7       24.3
# 4      5859.552246       31.2       22.5
#
# [5 rows x 25 columns]

# %%
df.tail()
# Out:
#       station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# 7747     23.0  30-08-2017          23.3          17.1    26.741310
# 7748     24.0  30-08-2017          23.3          17.7    24.040634
# 7749     25.0  30-08-2017          23.2          17.4    22.933014
# 7750      NaN         NaN          20.0          11.3    19.794666
# 7751      NaN         NaN          37.6          29.9    98.524734
#
#       LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_Tmin_lapse   LDAPS_WS    LDAPS_LH  \
# 7747    78.869858         26.352081         18.775678   6.148918   72.058294
# 7748    77.294975         27.010193         18.733519   6.542819   47.241457
# 7749    77.243744         27.939516         18.522965   7.289264    9.090034
# 7750    58.936283         17.624954         14.272646   2.882580  -13.603212
# 7751   100.000153         38.542255         29.619342  21.857621  213.414006
#
#       ...  LDAPS_PPT2  LDAPS_PPT3  LDAPS_PPT4      lat      lon       DEM  \
# 7747  ...    0.000000    0.000000    0.000000  37.5372  126.891   15.5876
# 7748  ...    0.000000    0.000000    0.000000  37.5237  126.909   17.2956
# 7749  ...    0.000000    0.000000    0.000000  37.5237  126.970   19.5844
# 7750  ...    0.000000    0.000000    0.000000  37.4562  126.826   12.3700
# 7751  ...   21.621661   15.841235   16.655469  37.6450  127.135  212.3350
#
#          Slope  Solar radiation  Next_Tmax  Next_Tmin
# 7747  0.155400      4443.313965       28.3       18.1
# 7748  0.222300      4438.373535       28.6       18.8
# 7749  0.271300      4451.345215       27.8       17.4
# 7750  0.098475      4329.520508       17.4       11.3
# 7751  5.178230      5992.895996       38.9       29.8
#
# [5 rows x 25 columns]

# %%
df.sample()
# Out:
#       station        Date  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# 6423     24.0  08-07-2017          28.0          25.1     69.50753
#
#       LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS   LDAPS_LH  \
# 6423    89.240257         30.864657         25.488907  5.682876  30.104292
#
#       ...  LDAPS_PPT2  LDAPS_PPT3  LDAPS_PPT4      lat      lon      DEM  \
# 6423  ...         0.0         0.0    0.038067  37.5237  126.909  17.2956
#
#        Slope  Solar radiation  Next_Tmax  Next_Tmin
# 6423  0.2223      5790.700195       31.5       23.8
#
# [1 rows x 25 columns]

# %% [markdown]
# # Exploratory Data Analysis(EDA)

# %%
df.shape
# Out:
# (7752, 25)

# %%
df.columns
# Out:
# Index(['station', 'Date', 'Present_Tmax', 'Present_Tmin', 'LDAPS_RHmin',
#        'LDAPS_RHmax', 'LDAPS_Tmax_lapse', 'LDAPS_Tmin_lapse', 'LDAPS_WS',
#        'LDAPS_LH', 'LDAPS_CC1', 'LDAPS_CC2', 'LDAPS_CC3', 'LDAPS_CC4',
#        'LDAPS_PPT1', 'LDAPS_PPT2', 'LDAPS_PPT3', 'LDAPS_PPT4', 'lat', 'lon',
#        'DEM', 'Slope', 'Solar radiation', 'Next_Tmax', 'Next_Tmin'],
#       dtype='object')

# %%
df.columns.to_list()
# Out:
# ['station',
#  'Date',
#  'Present_Tmax',
#  'Present_Tmin',
#  'LDAPS_RHmin',
#  'LDAPS_RHmax',
#  'LDAPS_Tmax_lapse',
#  'LDAPS_Tmin_lapse',
#  'LDAPS_WS',
#  'LDAPS_LH',
#  'LDAPS_CC1',
#  'LDAPS_CC2',
#  'LDAPS_CC3',
#  'LDAPS_CC4',
#  'LDAPS_PPT1',
#  'LDAPS_PPT2',
#  'LDAPS_PPT3',
#  'LDAPS_PPT4',
#  'lat',
#  'lon',
#  'DEM',
#  'Slope',
#  'Solar radiation',
#  'Next_Tmax',
#  'Next_Tmin']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7752 entries, 0 to 7751
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   station           7750 non-null   float64
#  1   Date              7750 non-null   object
#  2   Present_Tmax      7682 non-null   float64
#  3   Present_Tmin      7682 non-null   float64
#  4   LDAPS_RHmin       7677 non-null   float64
#  5   LDAPS_RHmax       7677 non-null   float64
#  6   LDAPS_Tmax_lapse  7677 non-null   float64
#  7   LDAPS_Tmin_lapse  7677 non-null   float64
#  8   LDAPS_WS          7677 non-null   float64
#  9   LDAPS_LH          7677 non-null   float64
#  10  LDAPS_CC1         7677 non-null   float64
#  11  LDAPS_CC2         7677 non-null   float64
#  12  LDAPS_CC3         7677 non-null   float64
#  13  LDAPS_CC4         7677 non-null   float64
#  14  LDAPS_PPT1        7677 non-null   float64
#  15  LDAPS_PPT2        7677 non-null   float64
#  16  LDAPS_PPT3        7677 non-null   float64
#  17  LDAPS_PPT4        7677 non-null   float64
#  18  lat               7752 non-null   float64
#  19  lon               7752 non-null   float64
#  20  DEM               7752 non-null   float64
#  21  Slope             7752 non-null   float64
#  22  Solar radiation   7752 non-null   float64
#  23  Next_Tmax         7725 non-null   float64
#  24  Next_Tmin         7725 non-null   float64
# dtypes: float64(24), object(1)
# memory usage: 1.5+ MB

# %%
df.isnull().sum()
# Out:
# station              2
# Date                 2
# Present_Tmax        70
# Present_Tmin        70
# LDAPS_RHmin         75
# LDAPS_RHmax         75
# LDAPS_Tmax_lapse    75
# LDAPS_Tmin_lapse    75
# LDAPS_WS            75
# LDAPS_LH            75
# LDAPS_CC1           75
# LDAPS_CC2           75
# LDAPS_CC3           75
# LDAPS_CC4           75
# LDAPS_PPT1          75
# LDAPS_PPT2          75
# LDAPS_PPT3          75
# LDAPS_PPT4          75
# lat                  0
# lon                  0
# DEM                  0
# Slope                0
# Solar radiation      0
# Next_Tmax           27
# Next_Tmin           27
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# As per above heatmap it is observed that there are few null values present in the dataset. Let's try to remove them.

# %%
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# station             0
# Date                0
# Present_Tmax        0
# Present_Tmin        0
# LDAPS_RHmin         0
# LDAPS_RHmax         0
# LDAPS_Tmax_lapse    0
# LDAPS_Tmin_lapse    0
# LDAPS_WS            0
# LDAPS_LH            0
# LDAPS_CC1           0
# LDAPS_CC2           0
# LDAPS_CC3           0
# LDAPS_CC4           0
# LDAPS_PPT1          0
# LDAPS_PPT2          0
# LDAPS_PPT3          0
# LDAPS_PPT4          0
# lat                 0
# lon                 0
# DEM                 0
# Slope               0
# Solar radiation     0
# Next_Tmax           0
# Next_Tmin           0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# Here we can observe that all the null values are removed and there are no values present in the dataset.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7588 entries, 0 to 7749
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   station           7588 non-null   float64
#  1   Date              7588 non-null   object
#  2   Present_Tmax      7588 non-null   float64
#  3   Present_Tmin      7588 non-null   float64
#  4   LDAPS_RHmin       7588 non-null   float64
#  5   LDAPS_RHmax       7588 non-null   float64
#  6   LDAPS_Tmax_lapse  7588 non-null   float64
#  7   LDAPS_Tmin_lapse  7588 non-null   float64
#  8   LDAPS_WS          7588 non-null   float64
#  9   LDAPS_LH          7588 non-null   float64
#  10  LDAPS_CC1         7588 non-null   float64
#  11  LDAPS_CC2         7588 non-null   float64
#  12  LDAPS_CC3         7588 non-null   float64
#  13  LDAPS_CC4         7588 non-null   float64
#  14  LDAPS_PPT1        7588 non-null   float64
#  15  LDAPS_PPT2        7588 non-null   float64
#  16  LDAPS_PPT3        7588 non-null   float64
#  17  LDAPS_PPT4        7588 non-null   float64
#  18  lat               7588 non-null   float64
#  19  lon               7588 non-null   float64
#  20  DEM               7588 non-null   float64
#  21  Slope             7588 non-null   float64
#  22  Solar radiation   7588 non-null   float64
#  23  Next_Tmax         7588 non-null   float64
#  24  Next_Tmin         7588 non-null   float64
# dtypes: float64(24), object(1)
# memory usage: 1.5+ MB

# %%
df.set_index('Date',inplace=True)

# %%
df
# Out:
#             station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# Date
# 30-06-2013      1.0          28.7          21.4    58.255688    91.116364
# 30-06-2013      2.0          31.9          21.6    52.263397    90.604721
# 30-06-2013      3.0          31.6          23.3    48.690479    83.973587
# 30-06-2013      4.0          32.0          23.4    58.239788    96.483688
# 30-06-2013      5.0          31.4          21.9    56.174095    90.155128
# ...             ...           ...           ...          ...          ...
# 30-08-2017     21.0          23.1          17.8    24.688997    78.261383
# 30-08-2017     22.0          22.5          17.4    30.094858    83.690018
# 30-08-2017     23.0          23.3          17.1    26.741310    78.869858
# 30-08-2017     24.0          23.3          17.7    24.040634    77.294975
# 30-08-2017     25.0          23.2          17.4    22.933014    77.243744
#
#             LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  \
# Date
# 30-06-2013         28.074101         23.006936  6.818887   69.451805
# 30-06-2013         29.850689         24.035009  5.691890   51.937448
# 30-06-2013         30.091292         24.565633  6.138224   20.573050
# 30-06-2013         29.704629         23.326177  5.650050   65.727144
# 30-06-2013         29.113934         23.486480  5.735004  107.965535
# ...                      ...               ...       ...         ...
# 30-08-2017         27.812697         18.303014  6.603253    9.614074
# 30-08-2017         26.704905         17.814038  5.768083   82.146707
# 30-08-2017         26.352081         18.775678  6.148918   72.058294
# 30-08-2017         27.010193         18.733519  6.542819   47.241457
# 30-08-2017         27.939516         18.522965  7.289264    9.090034
#
#             LDAPS_CC1  ...  LDAPS_PPT2  LDAPS_PPT3  LDAPS_PPT4      lat  \
# Date                   ...
# 30-06-2013   0.233947  ...         0.0         0.0         0.0  37.6046
# 30-06-2013   0.225508  ...         0.0         0.0         0.0  37.6046
# 30-06-2013   0.209344  ...         0.0         0.0         0.0  37.5776
# 30-06-2013   0.216372  ...         0.0         0.0         0.0  37.6450
# 30-06-2013   0.151407  ...         0.0         0.0         0.0  37.5507
# ...               ...  ...         ...         ...         ...      ...
# 30-08-2017   0.052902  ...         0.0         0.0         0.0  37.5507
# 30-08-2017   0.066461  ...         0.0         0.0         0.0  37.5102
# 30-08-2017   0.030034  ...         0.0         0.0         0.0  37.5372
# 30-08-2017   0.035874  ...         0.0         0.0         0.0  37.5237
# 30-08-2017   0.048954  ...         0.0         0.0         0.0  37.5237
#
#                 lon       DEM   Slope  Solar radiation  Next_Tmax  Next_Tmin
# Date
# 30-06-2013  126.991  212.3350  2.7850      5992.895996       29.1       21.2
# 30-06-2013  127.032   44.7624  0.5141      5869.312500       30.5       22.5
# 30-06-2013  127.058   33.3068  0.2661      5863.555664       31.1       23.9
# 30-06-2013  127.022   45.7160  2.5348      5856.964844       31.7       24.3
# 30-06-2013  127.135   35.0380  0.5055      5859.552246       31.2       22.5
# ...             ...       ...     ...              ...        ...        ...
# 30-08-2017  127.040   26.2980  0.5721      4456.024414       27.6       17.7
# 30-08-2017  127.086   21.9668  0.1332      4441.803711       28.0       17.1
# 30-08-2017  126.891   15.5876  0.1554      4443.313965       28.3       18.1
# 30-08-2017  126.909   17.2956  0.2223      4438.373535       28.6       18.8
# 30-08-2017  126.970   19.5844  0.2713      4451.345215       27.8       17.4
#
# [7588 rows x 24 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7588 entries, 30-06-2013 to 30-08-2017
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   station           7588 non-null   float64
#  1   Present_Tmax      7588 non-null   float64
#  2   Present_Tmin      7588 non-null   float64
#  3   LDAPS_RHmin       7588 non-null   float64
#  4   LDAPS_RHmax       7588 non-null   float64
#  5   LDAPS_Tmax_lapse  7588 non-null   float64
#  6   LDAPS_Tmin_lapse  7588 non-null   float64
#  7   LDAPS_WS          7588 non-null   float64
#  8   LDAPS_LH          7588 non-null   float64
#  9   LDAPS_CC1         7588 non-null   float64
#  10  LDAPS_CC2         7588 non-null   float64
#  11  LDAPS_CC3         7588 non-null   float64
#  12  LDAPS_CC4         7588 non-null   float64
#  13  LDAPS_PPT1        7588 non-null   float64
#  14  LDAPS_PPT2        7588 non-null   float64
#  15  LDAPS_PPT3        7588 non-null   float64
#  16  LDAPS_PPT4        7588 non-null   float64
#  17  lat               7588 non-null   float64
#  18  lon               7588 non-null   float64
#  19  DEM               7588 non-null   float64
#  20  Slope             7588 non-null   float64
#  21  Solar radiation   7588 non-null   float64
#  22  Next_Tmax         7588 non-null   float64
#  23  Next_Tmin         7588 non-null   float64
# dtypes: float64(24)
# memory usage: 1.4+ MB

# %%
for i in df.columns:
    print(df[i].value_counts())
# Out:
# 25.0    307
# 10.0    307
# 23.0    307
# 18.0    307
# 17.0    307
# 2.0     307
# 3.0     306
# 4.0     306
# 13.0    305
# 16.0    304
# 20.0    304
# 21.0    304
# 14.0    303
# 1.0     303
# 9.0     302
# 12.0    302
# 15.0    302
# 19.0    302
# 22.0    302
# 24.0    302
# 11.0    301
# 7.0     301
# 6.0     301
# 8.0     300
# 5.0     296
# Name: station, dtype: int64
# 31.4    112
# 29.4    108
# 29.1    106
# 29.2    105
# 30.6    105
#        ...
# 21.2      1
# 20.1      1
# 36.4      1
# 20.3      1
# 20.0      1
# Name: Present_Tmax, Length: 167, dtype: int64
# 24.0    160
# 23.8    153
# 23.5    143
# 23.1    143
# 23.3    140
#        ...
# 14.3      1
# 29.9      1
# 29.7      1
# 29.1      1
# 15.0      1
# Name: Present_Tmin, Length: 155, dtype: int64
# 77.030350    2
# 51.810596    2
# 71.658089    2
# 58.255688    1
# 46.582764    1
#             ..
# 58.950947    1
# 58.566174    1
# 59.790348    1
# 51.062355    1
# 22.933014    1
# Name: LDAPS_RHmin, Length: 7585, dtype: int64
# 92.531029    2
# 88.876610    2
# 85.863731    2
# 96.525200    2
# 96.058418    2
#             ..
# 84.423607    1
# 81.810715    1
# 92.785057    1
# 91.507935    1
# 77.243744    1
# Name: LDAPS_RHmax, Length: 7577, dtype: int64
# 28.074101    1
# 31.134897    1
# 33.447754    1
# 32.631448    1
# 30.795575    1
#             ..
# 27.737869    1
# 28.321177    1
# 27.629996    1
# 28.775293    1
# 27.939516    1
# Name: LDAPS_Tmax_lapse, Length: 7588, dtype: int64
# 23.006936    1
# 21.156704    1
# 24.222358    1
# 23.736497    1
# 23.064826    1
#             ..
# 22.034331    1
# 21.008695    1
# 21.839880    1
# 22.247555    1
# 18.522965    1
# Name: LDAPS_Tmin_lapse, Length: 7588, dtype: int64
# 6.818887    1
# 5.483732    1
# 6.749639    1
# 6.404110    1
# 8.349506    1
#            ..
# 7.595801    1
# 8.195843    1
# 7.852853    1
# 7.991329    1
# 7.289264    1
# Name: LDAPS_WS, Length: 7588, dtype: int64
# 69.451805     1
# 101.307648    1
# 16.204221     1
# 77.699182     1
# 119.922983    1
#              ..
# 68.288728     1
# 72.907605     1
# 65.992804     1
# 35.616482     1
# 9.090034      1
# Name: LDAPS_LH, Length: 7588, dtype: int64
# 0.000000    104
# 0.233947      1
# 0.280824      1
# 0.347618      1
# 0.372637      1
#            ...
# 0.011633      1
# 0.020428      1
# 0.021683      1
# 0.008280      1
# 0.048954      1
# Name: LDAPS_CC1, Length: 7485, dtype: int64
# 0.000000    93
# 0.203896     1
# 0.196689     1
# 0.021183     1
# 0.001433     1
#             ..
# 0.091687     1
# 0.086090     1
# 0.102609     1
# 0.076528     1
# 0.059869     1
# Name: LDAPS_CC2, Length: 7496, dtype: int64
# 0.000000e+00    75
# 8.680560e-04     2
# 5.810000e-07     2
# 1.616969e-01     1
# 8.667610e-02     1
#                 ..
# 6.616012e-01     1
# 6.588265e-01     1
# 5.463407e-01     1
# 5.650474e-01     1
# 5.850000e-07     1
# Name: LDAPS_CC3, Length: 7512, dtype: int64
# 0.000000    135
# 0.002604      7
# 0.001736      3
# 0.005208      3
# 0.373025      2
#            ...
# 0.048167      1
# 0.081127      1
# 0.092123      1
# 0.124582      1
# 0.000796      1
# Name: LDAPS_CC4, Length: 7438, dtype: int64
# 0.000000    4789
# 0.001953      11
# 0.002604       5
# 0.001734       3
# 0.002199       2
#             ...
# 0.266814       1
# 0.262156       1
# 0.288735       1
# 0.279363       1
# 2.040502       1
# Name: LDAPS_PPT1, Length: 2779, dtype: int64
# 0.000000    5094
# 0.001953       7
# 0.000040       3
# 0.000781       3
# 0.000086       2
#             ...
# 0.007427       1
# 0.087218       1
# 0.000695       1
# 0.047651       1
# 0.247997       1
# Name: LDAPS_PPT2, Length: 2479, dtype: int64
# 0.000000    5237
# 0.001953      10
# 0.000852       4
# 0.002604       3
# 0.001196       2
#             ...
# 0.038018       1
# 0.028196       1
# 0.003034       1
# 0.121254       1
# 0.021030       1
# Name: LDAPS_PPT3, Length: 2326, dtype: int64
# 0.000000    5690
# 0.001953       3
# 0.001105       2
# 0.001909       2
# 0.000046       2
#             ...
# 0.005363       1
# 0.001990       1
# 0.002798       1
# 0.016436       1
# 3.093815       1
# Name: LDAPS_PPT4, Length: 1892, dtype: int64
# 37.5776    1214
# 37.5507    1204
# 37.6181     611
# 37.6046     610
# 37.5237     609
# 37.5372     608
# 37.4967     605
# 37.4697     604
# 37.5102     603
# 37.4562     307
# 37.4832     307
# 37.6450     306
# Name: lat, dtype: int64
# 126.970    307
# 126.955    307
# 126.891    307
# 127.024    307
# 127.099    307
# 127.032    307
# 127.058    306
# 127.022    306
# 127.083    305
# 126.995    304
# 127.004    304
# 127.040    304
# 126.927    303
# 126.991    303
# 126.826    302
# 126.988    302
# 126.937    302
# 126.938    302
# 127.086    302
# 126.909    302
# 127.085    301
# 126.838    301
# 127.042    301
# 126.910    300
# 127.135    296
# Name: lon, dtype: int64
# 19.5844     307
# 208.5070    307
# 15.5876     307
# 56.4448     307
# 53.4712     307
# 44.7624     307
# 33.3068     306
# 45.7160     306
# 59.8324     305
# 82.2912     304
# 146.5540    304
# 26.2980     304
# 30.9680     303
# 212.3350    303
# 50.9312     302
# 132.1180    302
# 30.0464     302
# 75.0924     302
# 21.9668     302
# 17.2956     302
# 28.7000     301
# 12.3700     301
# 54.6384     301
# 52.5180     300
# 35.0380     296
# Name: DEM, dtype: int64
# 0.2713    307
# 5.1782    307
# 0.1554    307
# 1.2313    307
# 0.6970    307
# 0.5141    307
# 0.2661    306
# 2.5348    306
# 2.6865    305
# 2.2579    304
# 4.7296    304
# 0.5721    304
# 0.6180    303
# 2.7850    303
# 0.4125    302
# 0.5931    302
# 0.8552    302
# 1.7678    302
# 0.1332    302
# 0.2223    302
# 0.6233    301
# 0.0985    301
# 0.1457    301
# 1.5629    300
# 0.5055    296
# Name: Slope, dtype: int64
# 5455.486816    5
# 5356.832520    5
# 5209.735352    5
# 4543.530273    5
# 5232.047852    5
#               ..
# 4408.542480    1
# 4418.823730    1
# 4423.769531    1
# 4575.028809    1
# 4411.375977    1
# Name: Solar radiation, Length: 1575, dtype: int64
# 29.3    113
# 33.0    104
# 31.3    100
# 29.6     98
# 31.2     97
#        ...
# 37.5      1
# 38.7      1
# 37.4      1
# 20.9      1
# 17.4      1
# Name: Next_Tmax, Length: 181, dtype: int64
# 23.5    157
# 24.0    152
# 23.4    150
# 23.2    148
# 23.8    146
#        ...
# 29.8      1
# 28.5      1
# 29.1      1
# 29.4      1
# 12.9      1
# Name: Next_Tmin, Length: 157, dtype: int64

# %%
df.nunique().to_frame('No.of.unique.values')
# Out:
#                   No.of.unique.values
# station                            25
# Present_Tmax                      167
# Present_Tmin                      155
# LDAPS_RHmin                      7585
# LDAPS_RHmax                      7577
# LDAPS_Tmax_lapse                 7588
# LDAPS_Tmin_lapse                 7588
# LDAPS_WS                         7588
# LDAPS_LH                         7588
# LDAPS_CC1                        7485
# LDAPS_CC2                        7496
# LDAPS_CC3                        7512
# LDAPS_CC4                        7438
# LDAPS_PPT1                       2779
# LDAPS_PPT2                       2479
# LDAPS_PPT3                       2326
# LDAPS_PPT4                       1892
# lat                                12
# lon                                25
# DEM                                25
# Slope                              25
# Solar radiation                  1575
# Next_Tmax                         181
# Next_Tmin                         157

# %%
df.describe()
# Out:
#            station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# count  7588.000000   7588.000000   7588.000000  7588.000000  7588.000000
# mean     13.014101     29.748366     23.195809    56.724969    88.360823
# std       7.217858      2.967401      2.400880    14.626559     7.199456
# min       1.000000     20.000000     11.300000    19.794666    58.936283
# 25%       7.000000     27.800000     21.600000    45.960243    84.203724
# 50%      13.000000     29.900000     23.400000    55.023199    89.784122
# 75%      19.000000     32.000000     24.800000    67.115099    93.742725
# max      25.000000     37.600000     29.900000    98.524734   100.000153
#
#        LDAPS_Tmax_lapse  LDAPS_Tmin_lapse     LDAPS_WS     LDAPS_LH  \
# count       7588.000000       7588.000000  7588.000000  7588.000000
# mean          29.620128         23.511786     7.094097    62.492606
# std            2.943496          2.342579     2.177034    33.686158
# min           17.624954         14.272646     2.882580   -13.603212
# 25%           27.673756         22.086820     5.675358    37.206201
# 50%           29.709537         23.758249     6.547838    56.898324
# 75%           31.711109         25.155660     8.028960    84.235666
# max           38.542255         29.619342    21.857621   213.414006
#
#          LDAPS_CC1  ...   LDAPS_PPT2   LDAPS_PPT3   LDAPS_PPT4          lat  \
# count  7588.000000  ...  7588.000000  7588.000000  7588.000000  7588.000000
# mean      0.368510  ...     0.480738     0.275007     0.265373    37.544792
# std       0.262260  ...     1.743327     1.146087     1.179661     0.050428
# min       0.000000  ...     0.000000     0.000000     0.000000    37.456200
# 25%       0.146546  ...     0.000000     0.000000     0.000000    37.510200
# 50%       0.315706  ...     0.000000     0.000000     0.000000    37.550700
# 75%       0.574174  ...     0.017735     0.007855     0.000017    37.577600
# max       0.967277  ...    21.621661    15.841235    16.655469    37.645000
#
#               lon          DEM        Slope  Solar radiation    Next_Tmax  \
# count  7588.00000  7588.000000  7588.000000      7588.000000  7588.000000
# mean    126.99142    61.918136     1.259755      5343.724208    30.241526
# std       0.07922    54.323529     1.372748       429.782561     3.111807
# min     126.82600    12.370000     0.098500      4329.520508    17.400000
# 25%     126.93700    28.700000     0.271300      5001.485717    28.200000
# 50%     126.99500    45.716000     0.618000      5441.987305    30.400000
# 75%     127.04200    59.832400     1.767800      5729.485840    32.600000
# max     127.13500   212.335000     5.178200      5992.895996    38.900000
#
#          Next_Tmin
# count  7588.000000
# mean     22.910820
# std       2.482256
# min      11.300000
# 25%      21.300000
# 50%      23.100000
# 75%      24.600000
# max      29.800000
#
# [8 rows x 24 columns]

# %% [markdown]
# This gives the statistical information of the numerical columns. The summary of the dataset looks perfect since there is no negative/ invalid values present
#
# From the above description we can observe the following:
#
#     1) The counts of all the columns are same which means there are no missing values in the dataset.
#     2) Mean and median almost looks same which means there is no much skewness in the distribution.
#     3) Max values are higher compared to all other statistics data.
#     4) We can also notice the standard deviation, 25%, min values from this describe method.

# %% [markdown]
# # Univariate Analysis

# %%
plt.figure(figsize=(10,10))
sns.countplot(x='lat',data=df)
# Out:
# <Axes: xlabel='lat', ylabel='count'>

# %% [markdown]
# Temparature has latitude value of 37.5507 and 37.5776 with maximum compared to other values.

# %% [markdown]
# # Bi-Variate Analysis

# %%
plt.figure(figsize=(20,5))
sns.lineplot(x='Solar radiation',y='Next_Tmin',data=df)
plt.show()

# %% [markdown]
# Here we can observe that as solar radiation is increaing then there is increase in minimum temperature for next day.

# %%
plt.figure(figsize=(20,5))
sns.lineplot(x='Solar radiation',y='Next_Tmax',data=df)
plt.show()

# %% [markdown]
# Here we can observe that as solar radiation is increaing then there is increase in maximum temperature for next day.

# %%
sns.lineplot(x='station',y='Next_Tmin',data=df)
plt.show()

# %% [markdown]
# Next day minimum temperature is high at 18 and low at 17.

# %%
sns.lineplot(x='station',y='Next_Tmax',data=df)
plt.show()

# %% [markdown]
# Next day max temperature is high at 18 and low at 10.

# %%
sns.scatterplot(x='LDAPS_Tmax_lapse',y='Next_Tmax',data=df)
# Out:
# <Axes: xlabel='LDAPS_Tmax_lapse', ylabel='Next_Tmax'>

# %% [markdown]
# As LDAPS_Tmax_lapse is increasing there is increase in next day max temperature which means they have strong relation with each other.

# %%
sns.scatterplot(x='LDAPS_Tmin_lapse',y='Next_Tmin',data=df)
# Out:
# <Axes: xlabel='LDAPS_Tmin_lapse', ylabel='Next_Tmin'>

# %% [markdown]
# As LDAPS_Tmin_lapse is decreasing there is decrease in next day min temperature which means they have strong relation with each other.

# %%
sns.scatterplot(x='Present_Tmin',y='Next_Tmin',data=df)
# Out:
# <Axes: xlabel='Present_Tmin', ylabel='Next_Tmin'>

# %% [markdown]
# As present_Tmin is decreasing there is decrease in next_tmin which means they are strongly related to each other

# %%
sns.scatterplot(x='Present_Tmax',y='Next_Tmax',data=df)
# Out:
# <Axes: xlabel='Present_Tmax', ylabel='Next_Tmax'>

# %% [markdown]
# As present_Tmax is increasing there is increase in next_tmax which means they are strongly related to each other

# %% [markdown]
# # checking for skewness in distribution

# %%
plt.figure(figsize=(20,25),facecolor='white')
plotnumber=1

for col in df:
    if plotnumber<=25:
        plt.subplot(5,5,plotnumber)
        sns.distplot(df[col],color='m')
        plt.xlabel(col,fontsize=15)
        plt.yticks(rotation=0,fontsize=15)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# Here we can observe that skewness is present in LDAPS_PPT1, LDAPS_PPT2, LDAPS_PPT3 and LDAPS_PPT4.

# %% [markdown]
# # Checking for outliers

# %%
plt.figure(figsize=(20,25),facecolor='white')
plotnumber=1

for col in df:
    if plotnumber<=25:
        plt.subplot(5,5,plotnumber)
        sns.boxplot(df[col],color='m')
        plt.xlabel(col,fontsize=15)
        plt.yticks(rotation=0,fontsize=15)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# Outliers are present in Present_Tmax, Present_Tmin, LDAPS_RHmax, LDAPS_Tmax_lapse, LDAPS_Tmin_lapse, LDAPS_WS, LDAPS_LH, LDAPS_PPT1, LDAPS_PPT2, LDAPS_PPT3, LDAPS_PPT4, DEM, Slope, Next_Tmax, Next_Tmin.
#
# Let's try to remove them by using z-score

# %%
from scipy.stats import zscore

# %%
outliers=(df[['Present_Tmax','Present_Tmin','LDAPS_RHmax','LDAPS_Tmax_lapse','LDAPS_Tmin_lapse','LDAPS_WS','LDAPS_LH','LDAPS_PPT1','LDAPS_PPT2','LDAPS_PPT3','LDAPS_PPT4','DEM','Slope','Next_Tmax','Next_Tmin']])

# %%
z=np.abs(zscore(outliers))

# %%
z
# Out:
#             Present_Tmax  Present_Tmin  LDAPS_RHmax  LDAPS_Tmax_lapse  \
# Date
# 30-06-2013      0.353318      0.748029     0.382768          0.525269
# 30-06-2013      0.725138      0.664721     0.311697          0.078334
# 30-06-2013      0.624033      0.043400     0.609425          0.160080
# 30-06-2013      0.758840      0.085054     1.128335          0.028710
# 30-06-2013      0.556630      0.539758     0.249244          0.171981
# ...                  ...           ...          ...               ...
# 30-08-2017      2.240616      2.247578     1.402898          0.614083
# 30-08-2017      2.442826      2.414195     0.648815          0.990460
# 30-08-2017      2.173212      2.539157     1.318376          1.110333
# 30-08-2017      2.173212      2.289232     1.537141          0.886737
# 30-08-2017      2.206914      2.414195     1.544257          0.570995
#
#             LDAPS_Tmin_lapse  LDAPS_WS  LDAPS_LH  LDAPS_PPT1  LDAPS_PPT2  \
# Date
# 30-06-2013          0.215525  0.126423  0.206603    0.305589    0.275777
# 30-06-2013          0.223368  0.644133  0.313359    0.305589    0.275777
# 30-06-2013          0.449896  0.439100  1.244497    0.305589    0.275777
# 30-06-2013          0.079238  0.663353  0.096026    0.305589    0.275777
# 30-06-2013          0.010803  0.624327  1.349989    0.305589    0.275777
# ...                      ...       ...       ...         ...         ...
# 30-08-2017          2.223667  0.225479  1.569844    0.305589    0.275777
# 30-08-2017          2.432415  0.609132  0.583486    0.305589    0.275777
# 30-08-2017          2.021883  0.434188  0.283984    0.305589    0.275777
# 30-08-2017          2.039881  0.253241  0.452772    0.305589    0.275777
# 30-08-2017          2.129768  0.089654  1.585402    0.305589    0.275777
#
#             LDAPS_PPT3  LDAPS_PPT4       DEM     Slope  Next_Tmax  Next_Tmin
# Date
# 30-06-2013    0.239969    0.224971  2.769091  1.111162   0.366861   0.689265
# 30-06-2013    0.239969    0.224971  0.315828  0.543220   0.083068   0.165513
# 30-06-2013    0.239969    0.224971  0.526719  0.723891   0.275895   0.398527
# 30-06-2013    0.239969    0.224971  0.298272  0.928888   0.468721   0.559681
# 30-06-2013    0.239969    0.224971  0.494848  0.549485   0.308032   0.165513
# ...                ...         ...       ...       ...        ...        ...
# 30-08-2017    0.239969    0.224971  0.655747  0.500966   0.848928   2.099366
# 30-08-2017    0.239969    0.224971  0.735482  0.820711   0.720377   2.341098
# 30-08-2017    0.239969    0.224971  0.852919  0.804538   0.623964   1.938212
# 30-08-2017    0.239969    0.224971  0.821476  0.755800   0.527550   1.656192
# 30-08-2017    0.239969    0.224971  0.779341  0.720103   0.784652   2.220232
#
# [7588 rows x 15 columns]

# %%
threshold=3
np.where(z>3)
# Out:
# (array([  25,   25,   26, ..., 7581, 7582, 7582], dtype=int64),
#  array([5, 8, 8, ..., 1, 1, 4], dtype=int64))

# %%
z.iloc[25,5]
# Out:
# 3.911059950709196

# %%
z.iloc[26,8]
# Out:
# 6.512507233943351

# %%
z.iloc[7582,4]
# Out:
# 3.3038886102197513

# %%
df1=df[(z<3).all(axis=1)]

# %%
df1
# Out:
#             station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# Date
# 30-06-2013      1.0          28.7          21.4    58.255688    91.116364
# 30-06-2013      2.0          31.9          21.6    52.263397    90.604721
# 30-06-2013      3.0          31.6          23.3    48.690479    83.973587
# 30-06-2013      4.0          32.0          23.4    58.239788    96.483688
# 30-06-2013      5.0          31.4          21.9    56.174095    90.155128
# ...             ...           ...           ...          ...          ...
# 30-08-2017     21.0          23.1          17.8    24.688997    78.261383
# 30-08-2017     22.0          22.5          17.4    30.094858    83.690018
# 30-08-2017     23.0          23.3          17.1    26.741310    78.869858
# 30-08-2017     24.0          23.3          17.7    24.040634    77.294975
# 30-08-2017     25.0          23.2          17.4    22.933014    77.243744
#
#             LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS    LDAPS_LH  \
# Date
# 30-06-2013         28.074101         23.006936  6.818887   69.451805
# 30-06-2013         29.850689         24.035009  5.691890   51.937448
# 30-06-2013         30.091292         24.565633  6.138224   20.573050
# 30-06-2013         29.704629         23.326177  5.650050   65.727144
# 30-06-2013         29.113934         23.486480  5.735004  107.965535
# ...                      ...               ...       ...         ...
# 30-08-2017         27.812697         18.303014  6.603253    9.614074
# 30-08-2017         26.704905         17.814038  5.768083   82.146707
# 30-08-2017         26.352081         18.775678  6.148918   72.058294
# 30-08-2017         27.010193         18.733519  6.542819   47.241457
# 30-08-2017         27.939516         18.522965  7.289264    9.090034
#
#             LDAPS_CC1  ...  LDAPS_PPT2  LDAPS_PPT3  LDAPS_PPT4      lat  \
# Date                   ...
# 30-06-2013   0.233947  ...         0.0         0.0         0.0  37.6046
# 30-06-2013   0.225508  ...         0.0         0.0         0.0  37.6046
# 30-06-2013   0.209344  ...         0.0         0.0         0.0  37.5776
# 30-06-2013   0.216372  ...         0.0         0.0         0.0  37.6450
# 30-06-2013   0.151407  ...         0.0         0.0         0.0  37.5507
# ...               ...  ...         ...         ...         ...      ...
# 30-08-2017   0.052902  ...         0.0         0.0         0.0  37.5507
# 30-08-2017   0.066461  ...         0.0         0.0         0.0  37.5102
# 30-08-2017   0.030034  ...         0.0         0.0         0.0  37.5372
# 30-08-2017   0.035874  ...         0.0         0.0         0.0  37.5237
# 30-08-2017   0.048954  ...         0.0         0.0         0.0  37.5237
#
#                 lon       DEM   Slope  Solar radiation  Next_Tmax  Next_Tmin
# Date
# 30-06-2013  126.991  212.3350  2.7850      5992.895996       29.1       21.2
# 30-06-2013  127.032   44.7624  0.5141      5869.312500       30.5       22.5
# 30-06-2013  127.058   33.3068  0.2661      5863.555664       31.1       23.9
# 30-06-2013  127.022   45.7160  2.5348      5856.964844       31.7       24.3
# 30-06-2013  127.135   35.0380  0.5055      5859.552246       31.2       22.5
# ...             ...       ...     ...              ...        ...        ...
# 30-08-2017  127.040   26.2980  0.5721      4456.024414       27.6       17.7
# 30-08-2017  127.086   21.9668  0.1332      4441.803711       28.0       17.1
# 30-08-2017  126.891   15.5876  0.1554      4443.313965       28.3       18.1
# 30-08-2017  126.909   17.2956  0.2223      4438.373535       28.6       18.8
# 30-08-2017  126.970   19.5844  0.2713      4451.345215       27.8       17.4
#
# [6739 rows x 24 columns]

# %%
print('The old dimensions are:',df.shape[0])
print('The new dimensions are:',df1.shape[0])
# Out:
# The old dimensions are: 7588
# The new dimensions are: 6739

# %%
print('Data Loss percentage:',((df.shape[0]-df1.shape[0])/df.shape[0])*100)
# Out:
# Data Loss percentage: 11.188719030047443

# %% [markdown]
# # Checking for skewness

# %%
df1.skew()
# Out:
# station            -0.001594
# Present_Tmax       -0.269936
# Present_Tmin       -0.221250
# LDAPS_RHmin         0.309567
# LDAPS_RHmax        -0.686083
# LDAPS_Tmax_lapse   -0.110563
# LDAPS_Tmin_lapse   -0.379269
# LDAPS_WS            1.085685
# LDAPS_LH            0.567050
# LDAPS_CC1           0.594835
# LDAPS_CC2           0.505774
# LDAPS_CC3           0.701288
# LDAPS_CC4           0.708754
# LDAPS_PPT1          3.724580
# LDAPS_PPT2          4.854967
# LDAPS_PPT3          5.516862
# LDAPS_PPT4          5.924324
# lat                 0.106983
# lon                -0.277547
# DEM                 1.764698
# Slope               1.590130
# Solar radiation    -0.520157
# Next_Tmax          -0.267526
# Next_Tmin          -0.234328
# dtype: float64

# %% [markdown]
# Skewness is present in LDAPS_PPT1, LDAPS_PPT2, LDAPS_PPT3 and LDAPS_PPT4. Let's try to remove them by using cube root method.

# %%
df1['LDAPS_PPT1']=np.cbrt(df1['LDAPS_PPT1'])
df1['LDAPS_PPT2']=np.cbrt(df1['LDAPS_PPT2'])
df1['LDAPS_PPT3']=np.cbrt(df1['LDAPS_PPT3'])
df1['LDAPS_PPT4']=np.cbrt(df1['LDAPS_PPT4'])

# %%
df1.skew()
# Out:
# station            -0.001594
# Present_Tmax       -0.269936
# Present_Tmin       -0.221250
# LDAPS_RHmin         0.309567
# LDAPS_RHmax        -0.686083
# LDAPS_Tmax_lapse   -0.110563
# LDAPS_Tmin_lapse   -0.379269
# LDAPS_WS            1.085685
# LDAPS_LH            0.567050
# LDAPS_CC1           0.594835
# LDAPS_CC2           0.505774
# LDAPS_CC3           0.701288
# LDAPS_CC4           0.708754
# LDAPS_PPT1          1.923134
# LDAPS_PPT2          2.341898
# LDAPS_PPT3          2.504981
# LDAPS_PPT4          2.848397
# lat                 0.106983
# lon                -0.277547
# DEM                 1.764698
# Slope               1.590130
# Solar radiation    -0.520157
# Next_Tmax          -0.267526
# Next_Tmin          -0.234328
# dtype: float64

# %%
df1['LDAPS_PPT2']=np.cbrt(df1['LDAPS_PPT2'])
df1['LDAPS_PPT3']=np.cbrt(df1['LDAPS_PPT3'])
df1['LDAPS_PPT4']=np.cbrt(df1['LDAPS_PPT4'])

# %%
df1.skew()
# Out:
# station            -0.001594
# Present_Tmax       -0.269936
# Present_Tmin       -0.221250
# LDAPS_RHmin         0.309567
# LDAPS_RHmax        -0.686083
# LDAPS_Tmax_lapse   -0.110563
# LDAPS_Tmin_lapse   -0.379269
# LDAPS_WS            1.085685
# LDAPS_LH            0.567050
# LDAPS_CC1           0.594835
# LDAPS_CC2           0.505774
# LDAPS_CC3           0.701288
# LDAPS_CC4           0.708754
# LDAPS_PPT1          1.923134
# LDAPS_PPT2          1.208771
# LDAPS_PPT3          1.311507
# LDAPS_PPT4          1.679208
# lat                 0.106983
# lon                -0.277547
# DEM                 1.764698
# Slope               1.590130
# Solar radiation    -0.520157
# Next_Tmax          -0.267526
# Next_Tmin          -0.234328
# dtype: float64

# %%
sns.distplot(df1['LDAPS_PPT2'])
# Out:
# <Axes: xlabel='LDAPS_PPT2', ylabel='Density'>

# %% [markdown]
# # Correlation

# %%
cor=df1.corr()

# %%
cor
# Out:
#                    station  Present_Tmax  Present_Tmin  LDAPS_RHmin  \
# station           1.000000      0.110291      0.133638    -0.069582
# Present_Tmax      0.110291      1.000000      0.610428    -0.154266
# Present_Tmin      0.133638      0.610428      1.000000     0.151385
# LDAPS_RHmin      -0.069582     -0.154266      0.151385     1.000000
# LDAPS_RHmax      -0.176388     -0.297804     -0.039688     0.552581
# LDAPS_Tmax_lapse  0.066863      0.540680      0.441577    -0.555583
# LDAPS_Tmin_lapse  0.104401      0.616886      0.764258     0.129481
# LDAPS_WS          0.023075     -0.105162      0.018711     0.236324
# LDAPS_LH         -0.135023      0.130771     -0.004055    -0.035217
# LDAPS_CC1         0.008671     -0.290078      0.090828     0.574389
# LDAPS_CC2         0.006380     -0.157917      0.117894     0.713238
# LDAPS_CC3         0.006875     -0.060549      0.041457     0.653782
# LDAPS_CC4         0.011167     -0.049339     -0.006979     0.458417
# LDAPS_PPT1       -0.001758     -0.135546      0.073741     0.289740
# LDAPS_PPT2       -0.021036     -0.040151      0.084705     0.376428
# LDAPS_PPT3        0.002851     -0.015137      0.036206     0.257765
# LDAPS_PPT4        0.015223     -0.042837     -0.055364     0.185176
# lat              -0.241811     -0.052041     -0.072707     0.090054
# lon              -0.122829      0.011132     -0.043201    -0.093969
# DEM              -0.257894     -0.168792     -0.241396     0.094391
# Slope            -0.096863     -0.091336     -0.138107     0.119216
# Solar radiation  -0.032810     -0.059891      0.020030     0.251733
# Next_Tmax         0.106378      0.586943      0.438813    -0.433872
# Next_Tmin         0.129110      0.615950      0.785946     0.134518
#
#                   LDAPS_RHmax  LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS  \
# station             -0.176388          0.066863          0.104401  0.023075
# Present_Tmax        -0.297804          0.540680          0.616886 -0.105162
# Present_Tmin        -0.039688          0.441577          0.764258  0.018711
# LDAPS_RHmin          0.552581         -0.555583          0.129481  0.236324
# LDAPS_RHmax          1.000000         -0.385695         -0.142575  0.094523
# LDAPS_Tmax_lapse    -0.385695          1.000000          0.621299 -0.229614
# LDAPS_Tmin_lapse    -0.142575          0.621299          1.000000 -0.052648
# LDAPS_WS             0.094523         -0.229614         -0.052648  1.000000
# LDAPS_LH             0.274590          0.036340         -0.135842 -0.045067
# LDAPS_CC1            0.409436         -0.416255          0.037375  0.257654
# LDAPS_CC2            0.360372         -0.492392          0.102180  0.220722
# LDAPS_CC3            0.167666         -0.500630          0.021654  0.180543
# LDAPS_CC4            0.049217         -0.384825         -0.027327  0.180312
# LDAPS_PPT1           0.308453         -0.182235         -0.010311  0.179201
# LDAPS_PPT2           0.225832         -0.237892          0.012282  0.115051
# LDAPS_PPT3           0.120010         -0.141172          0.012854  0.121172
# LDAPS_PPT4           0.106028         -0.160177         -0.081221  0.196309
# lat                  0.200216         -0.038285         -0.090587 -0.014440
# lon                  0.018945          0.106354         -0.024177 -0.077116
# DEM                  0.172348         -0.162061         -0.177845  0.150448
# Slope                0.218465         -0.148246         -0.172382  0.118546
# Solar radiation      0.153673          0.012974          0.106033  0.136180
# Next_Tmax           -0.301797          0.816861          0.546479 -0.277823
# Next_Tmin           -0.097490          0.553227          0.875382 -0.013668
#
#                   LDAPS_LH  LDAPS_CC1  ...  LDAPS_PPT2  LDAPS_PPT3  \
# station          -0.135023   0.008671  ...   -0.021036    0.002851
# Present_Tmax      0.130771  -0.290078  ...   -0.040151   -0.015137
# Present_Tmin     -0.004055   0.090828  ...    0.084705    0.036206
# LDAPS_RHmin      -0.035217   0.574389  ...    0.376428    0.257765
# LDAPS_RHmax       0.274590   0.409436  ...    0.225832    0.120010
# LDAPS_Tmax_lapse  0.036340  -0.416255  ...   -0.237892   -0.141172
# LDAPS_Tmin_lapse -0.135842   0.037375  ...    0.012282    0.012854
# LDAPS_WS         -0.045067   0.257654  ...    0.115051    0.121172
# LDAPS_LH          1.000000  -0.144578  ...   -0.066290    0.010732
# LDAPS_CC1        -0.144578   1.000000  ...    0.394805    0.191398
# LDAPS_CC2        -0.257382   0.759430  ...    0.479776    0.248135
# LDAPS_CC3        -0.239438   0.497133  ...    0.335930    0.344256
# LDAPS_CC4        -0.164953   0.333113  ...    0.224683    0.191881
# LDAPS_PPT1       -0.000963   0.545002  ...    0.323110    0.092851
# LDAPS_PPT2       -0.066290   0.394805  ...    1.000000    0.233893
# LDAPS_PPT3        0.010732   0.191398  ...    0.233893    1.000000
# LDAPS_PPT4        0.038641   0.196073  ...    0.155632    0.248729
# lat               0.124764  -0.006352  ...    0.047246    0.027587
# lon               0.021578  -0.013794  ...    0.023355    0.002660
# DEM               0.068085  -0.030685  ...    0.000348    0.013590
# Slope             0.100776  -0.036418  ...    0.012988    0.028117
# Solar radiation  -0.031060   0.244497  ...    0.083514   -0.037470
# Next_Tmax         0.176077  -0.453763  ...   -0.211431   -0.131137
# Next_Tmin        -0.046540   0.008400  ...    0.004340    0.023274
#
#                   LDAPS_PPT4       lat       lon       DEM     Slope  \
# station             0.015223 -0.241811 -0.122829 -0.257894 -0.096863
# Present_Tmax       -0.042837 -0.052041  0.011132 -0.168792 -0.091336
# Present_Tmin       -0.055364 -0.072707 -0.043201 -0.241396 -0.138107
# LDAPS_RHmin         0.185176  0.090054 -0.093969  0.094391  0.119216
# LDAPS_RHmax         0.106028  0.200216  0.018945  0.172348  0.218465
# LDAPS_Tmax_lapse   -0.160177 -0.038285  0.106354 -0.162061 -0.148246
# LDAPS_Tmin_lapse   -0.081221 -0.090587 -0.024177 -0.177845 -0.172382
# LDAPS_WS            0.196309 -0.014440 -0.077116  0.150448  0.118546
# LDAPS_LH            0.038641  0.124764  0.021578  0.068085  0.100776
# LDAPS_CC1           0.196073 -0.006352 -0.013794 -0.030685 -0.036418
# LDAPS_CC2           0.188292 -0.002066 -0.013838 -0.028371 -0.032839
# LDAPS_CC3           0.304370 -0.005312  0.005797 -0.014158 -0.018414
# LDAPS_CC4           0.346915 -0.019955 -0.014148 -0.025252 -0.031571
# LDAPS_PPT1          0.149145  0.012605  0.018262 -0.008757 -0.006454
# LDAPS_PPT2          0.155632  0.047246  0.023355  0.000348  0.012988
# LDAPS_PPT3          0.248729  0.027587  0.002660  0.013590  0.028117
# LDAPS_PPT4          1.000000 -0.003048 -0.000335 -0.030160 -0.026325
# lat                -0.003048  1.000000  0.286414  0.026804  0.070589
# lon                -0.000335  0.286414  1.000000  0.009622  0.042559
# DEM                -0.030160  0.026804  0.009622  1.000000  0.780862
# Slope              -0.026325  0.070589  0.042559  0.780862  1.000000
# Solar radiation    -0.019200  0.049502  0.012536  0.060443  0.033586
# Next_Tmax          -0.154875 -0.048616  0.010567 -0.151929 -0.083907
# Next_Tmin          -0.106821 -0.076705 -0.041574 -0.237683 -0.136838
#
#                   Solar radiation  Next_Tmax  Next_Tmin
# station                 -0.032810   0.106378   0.129110
# Present_Tmax            -0.059891   0.586943   0.615950
# Present_Tmin             0.020030   0.438813   0.785946
# LDAPS_RHmin              0.251733  -0.433872   0.134518
# LDAPS_RHmax              0.153673  -0.301797  -0.097490
# LDAPS_Tmax_lapse         0.012974   0.816861   0.553227
# LDAPS_Tmin_lapse         0.106033   0.546479   0.875382
# LDAPS_WS                 0.136180  -0.277823  -0.013668
# LDAPS_LH                -0.031060   0.176077  -0.046540
# LDAPS_CC1                0.244497  -0.453763   0.008400
# LDAPS_CC2                0.187202  -0.484796   0.078871
# LDAPS_CC3                0.123609  -0.492707   0.000194
# LDAPS_CC4                0.091023  -0.427087  -0.041994
# LDAPS_PPT1               0.138903  -0.233124  -0.029752
# LDAPS_PPT2               0.083514  -0.211431   0.004340
# LDAPS_PPT3              -0.037470  -0.131137   0.023274
# LDAPS_PPT4              -0.019200  -0.154875  -0.106821
# lat                      0.049502  -0.048616  -0.076705
# lon                      0.012536   0.010567  -0.041574
# DEM                      0.060443  -0.151929  -0.237683
# Slope                    0.033586  -0.083907  -0.136838
# Solar radiation          1.000000  -0.021477   0.083207
# Next_Tmax               -0.021477   1.000000   0.580951
# Next_Tmin                0.083207   0.580951   1.000000
#
# [24 rows x 24 columns]

# %%
plt.figure(figsize=(20,20))
sns.heatmap(cor,cmap='Blues',annot=True)
# Out:
# <Axes: >

# %% [markdown]
# Here we can observe the following:
#
#     1) Present_Tmax is strongly corelated with Next_Tmax, Next_Tmin, LDAPS_Tmax_lapse, LDAPS_Tmin_lapse and Present_Tmin.
#     2) Present_Tmin is strongly correlated with Next_Tmax, Next_Tmin, LDAPS_Tmax_lapse, LDAPS_Tmin_lapse and Present_Tmax.
#     3) Next_Tmax is strongly correlated with Next_Tmin, LDAPS_Tmax_lapse, LDAPS_Tmin_lapse, Present_Tmax and Present_Tmin.
#     4) Next_Tmin is strongly correlated with Next_Tmax, LDAPS_Tmax_lapse, LDAPS_Tmin_lapse, Present_Tmax and Present_Tmin.
#     5) All the other data are perfect correlated with each other along with negative correlation.

# %%
cor['Next_Tmax'].sort_values(ascending=False)
# Out:
# Next_Tmax           1.000000
# LDAPS_Tmax_lapse    0.816861
# Present_Tmax        0.586943
# Next_Tmin           0.580951
# LDAPS_Tmin_lapse    0.546479
# Present_Tmin        0.438813
# LDAPS_LH            0.176077
# station             0.106378
# lon                 0.010567
# Solar radiation    -0.021477
# lat                -0.048616
# Slope              -0.083907
# LDAPS_PPT3         -0.131137
# DEM                -0.151929
# LDAPS_PPT4         -0.154875
# LDAPS_PPT2         -0.211431
# LDAPS_PPT1         -0.233124
# LDAPS_WS           -0.277823
# LDAPS_RHmax        -0.301797
# LDAPS_CC4          -0.427087
# LDAPS_RHmin        -0.433872
# LDAPS_CC1          -0.453763
# LDAPS_CC2          -0.484796
# LDAPS_CC3          -0.492707
# Name: Next_Tmax, dtype: float64

# %%
plt.figure(figsize=(22,7))
cor['Next_Tmax'].sort_values(ascending=False).drop(['Next_Tmax']).plot(kind='bar',color='m')
plt.xlabel('Features')
plt.ylabel('Target')
plt.title('Correlation between target and features')
plt.show()

# %% [markdown]
# Target is least correlated with longitude compared to all other data.

# %%
x=df1.drop('Next_Tmax',axis=1)
y=df1['Next_Tmax']

# %% [markdown]
# # Standard Scalarization

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)

# %%
x
# Out:
#        station  Present_Tmax  Present_Tmin  LDAPS_RHmin  LDAPS_RHmax  \
# 0    -1.672719     -0.425704     -0.814460     0.195915     0.437537
# 1    -1.533959      0.690215     -0.727785    -0.236604     0.364239
# 2    -1.395198      0.585598      0.008945    -0.494494    -0.585732
# 3    -1.256438      0.725088      0.052282     0.194767     1.206456
# 4    -1.117678      0.515853     -0.597774     0.045667     0.299831
# ...        ...           ...           ...          ...          ...
# 6734  1.102482     -2.378563     -2.374595    -2.226900    -1.404059
# 6735  1.241243     -2.587798     -2.547943    -1.836710    -0.626356
# 6736  1.380003     -2.308818     -2.677955    -2.078766    -1.316889
# 6737  1.518763     -2.308818     -2.417932    -2.273699    -1.542506
# 6738  1.657523     -2.343691     -2.547943    -2.353646    -1.549845
#
#       LDAPS_Tmax_lapse  LDAPS_Tmin_lapse  LDAPS_WS  LDAPS_LH  LDAPS_CC1  ...  \
# 0            -0.662498         -0.289928 -0.020735  0.225115  -0.440130  ...
# 1            -0.016693          0.171379 -0.631488 -0.298746  -0.473686  ...
# 2             0.070769          0.409475 -0.389607 -1.236867  -0.537958  ...
# 3            -0.069787         -0.146681 -0.654162  0.113709  -0.510012  ...
# 4            -0.284509         -0.074752 -0.608123  1.377075  -0.768323  ...
# ...                ...               ...       ...       ...        ...  ...
# 6734         -0.757521         -2.400625 -0.137593 -1.564654  -1.159992  ...
# 6735         -1.160213         -2.620034 -0.590197  0.604824  -1.106080  ...
# 6736         -1.288468         -2.188536 -0.383811  0.303076  -1.250919  ...
# 6737         -1.049238         -2.207453 -0.170344 -0.439205  -1.227700  ...
# 6738         -0.711421         -2.301931  0.234177 -1.580329  -1.175693  ...
#
#       LDAPS_PPT1  LDAPS_PPT2  LDAPS_PPT3  LDAPS_PPT4       lat       lon  \
# 0      -0.539276   -0.611363   -0.581871   -0.498275  1.211166  0.002925
# 1      -0.539276   -0.611363   -0.581871   -0.498275  1.211166  0.518733
# 2      -0.539276   -0.611363   -0.581871   -0.498275  0.671467  0.845830
# 3      -0.539276   -0.611363   -0.581871   -0.498275  2.018714  0.392926
# 4      -0.539276   -0.611363   -0.581871   -0.498275  0.133768  1.814542
# ...          ...         ...         ...         ...       ...       ...
# 6734   -0.539276   -0.611363   -0.581871   -0.498275  0.133768  0.619378
# 6735   -0.539276   -0.611363   -0.581871   -0.498275 -0.675779  1.198089
# 6736   -0.539276   -0.611363   -0.581871   -0.498275 -0.136081 -1.255142
# 6737   -0.539276   -0.611363   -0.581871   -0.498275 -0.405930 -1.028689
# 6738   -0.539276   -0.611363   -0.581871   -0.498275 -0.405930 -0.261269
#
#            DEM     Slope  Solar radiation  Next_Tmin
# 0     2.828736  1.143153         1.543068  -0.790587
# 1    -0.304406 -0.536509         1.249502  -0.239151
# 2    -0.518594 -0.719941         1.235827   0.354704
# 3    -0.286576  0.958094         1.220170   0.524376
# 4    -0.486225 -0.542870         1.226317  -0.239151
# ...        ...       ...              ...        ...
# 6734 -0.649639 -0.493610        -2.107693  -2.275223
# 6735 -0.730620 -0.818240        -2.141474  -2.529732
# 6736 -0.849894 -0.801820        -2.137886  -2.105550
# 6737 -0.817959 -0.752338        -2.149622  -1.808623
# 6738 -0.775165 -0.716095        -2.118808  -2.402477
#
# [6739 rows x 23 columns]

# %% [markdown]
# # Variance Inflation Factor(VIF)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
VIF=pd.DataFrame()
VIF['VIF Values']=[variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
VIF['Feature']=x.columns
VIF
# Out:
#     VIF Values           Feature
# 0     1.232009           station
# 1     2.789333      Present_Tmax
# 2     3.326094      Present_Tmin
# 3     5.953930       LDAPS_RHmin
# 4     2.264384       LDAPS_RHmax
# 5     6.813194  LDAPS_Tmax_lapse
# 6     8.887649  LDAPS_Tmin_lapse
# 7     1.218696          LDAPS_WS
# 8     1.529234          LDAPS_LH
# 9     4.855272         LDAPS_CC1
# 10    5.489281         LDAPS_CC2
# 11    5.012647         LDAPS_CC3
# 12    3.167857         LDAPS_CC4
# 13    2.673014        LDAPS_PPT1
# 14    2.581372        LDAPS_PPT2
# 15    1.810390        LDAPS_PPT3
# 16    1.877600        LDAPS_PPT4
# 17    1.229849               lat
# 18    1.174790               lon
# 19    3.309741               DEM
# 20    3.046819             Slope
# 21    1.235508   Solar radiation
# 22    5.686306         Next_Tmin

# %% [markdown]
# There's no multicolinearity issue, so we can proceed further for model building.

# %% [markdown]
# # Model Building

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error, mean_absolute_error

# %%
maxAccu=0
maxRs=0

for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=i)
    LR=LinearRegression()
    LR.fit(x_train,y_train)
    pred_LR=LR.predict(x_test)
    r2=r2_score(y_test,pred_LR)
    if r2>maxAccu:
        maxAccu=r2
        maxRs=i
print('Best R2 score is',maxAccu, 'at random state', maxRs)
# Out:
# Best R2 score is 0.7975233998722745 at random state 43

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=i)

# %%
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.ensemble import GradientBoostingRegressor, AdaBoostRegressor, ExtraTreesRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.svm import SVR

# %%
LR=LinearRegression()
LR.fit(x_train,y_train)
pred_LR=LR.predict(x_test)
print('r2_score:',r2_score(y_test,pred_LR))
print('mean_squared_error:',mean_squared_error(y_test,pred_LR))
print('mean_absolute_error:',mean_absolute_error(y_test,pred_LR))
print('root_mean_squared_error:',np.sqrt(mean_squared_error(y_test,pred_LR)))
# Out:
# r2_score: 0.7955398437832839
# mean_squared_error: 1.8158290448960324
# mean_absolute_error: 1.0271337270009042
# root_mean_squared_error: 1.3475270108224295

# %%
Ls=Lasso()
Ls.fit(x_train,y_train)
pred_Ls=Ls.predict(x_test)
print('r2_score:',r2_score(y_test,pred_Ls))
print('mean_squared_error:',mean_squared_error(y_test,pred_Ls))
print('mean_absolute_error:',mean_absolute_error(y_test,pred_Ls))
print('root_mean_squared_error:',np.sqrt(mean_squared_error(y_test,pred_Ls)))
# Out:
# r2_score: 0.5510918522966539
# mean_squared_error: 3.9867936529707624
# mean_absolute_error: 1.5963729509185514
# root_mean_squared_error: 1.9966956836159993

# %%
Rd=Ridge()
Rd.fit(x_train,y_train)
pred_Rd=Rd.predict(x_test)
print('r2_score:',r2_score(y_test,pred_Rd))
print('mean_squared_error:',mean_squared_error(y_test,pred_Rd))
print('mean_absolute_error:',mean_absolute_error(y_test,pred_Rd))
print('root_mean_squared_error:',np.sqrt(mean_squared_error(y_test,pred_Rd)))
# Out:
# r2_score: 0.7955269597322143
# mean_squared_error: 1.8159434693129022
# mean_absolute_error: 1.0271560120272496
# root_mean_squared_error: 1.3475694673421856

# %%
ETR=ExtraTreesRegressor()
ETR.fit(x_train,y_train)
pred_ETR=ETR.predict(x_test)
print('r2_score:',r2_score(y_test,pred_ETR))
print('mean_squared_error:',mean_squared_error(y_test,pred_ETR))
print('mean_absolute_error:',mean_absolute_error(y_test,pred_ETR))
print('root_mean_squared_error:',np.sqrt(mean_squared_error(y_test,pred_ETR)))
# Out:
# r2_score: 0.9117973271793804
# mean_squared_error: 0.7833358738872399
# mean_absolute_error: 0.6607917903066269
# root_mean_squared_error: 0.8850626383975543

# %%
ABR=AdaBoostRegressor()
ABR.fit(x_train,y_train)
pred_ABR=ABR.predict(x_test)
print('r2_score:',r2_score(y_test,pred_ABR))
print('mean_squared_error:',mean_squared_error(y_test,pred_ABR))
print('mean_absolute_error:',mean_absolute_error(y_test,pred_ABR))
print('root_mean_squared_error:',np.sqrt(mean_squared_error(y_test,pred_ABR)))
# Out:
# r2_score: 0.7703564809809813
# mean_squared_error: 2.0394847559681963
# mean_absolute_error: 1.1467942273535285
# root_mean_squared_error: 1.4281053028289603

# %%
GBR=GradientBoostingRegressor()
GBR.fit(x_train,y_train)
pred_GBR=GBR.predict(x_test)
print('r2_score:',r2_score(y_test,pred_GBR))
print('mean_squared_error:',mean_squared_error(y_test,pred_GBR))
print('mean_absolute_error:',mean_absolute_error(y_test,pred_GBR))
print('root_mean_squared_error:',np.sqrt(mean_squared_error(y_test,pred_GBR)))
# Out:
# r2_score: 0.8478002826474077
# mean_squared_error: 1.351699384895651
# mean_absolute_error: 0.8916782084080691
# root_mean_squared_error: 1.1626260726887432

# %%
KNN=KNN()
KNN.fit(x_train,y_train)
pred_KNN=KNN.predict(x_test)
print('r2_score:',r2_score(y_test,pred_KNN))
print('mean_squared_error:',mean_squared_error(y_test,pred_KNN))
print('mean_absolute_error:',mean_absolute_error(y_test,pred_KNN))
print('root_mean_squared_error:',np.sqrt(mean_squared_error(y_test,pred_KNN)))
# Out:
# r2_score: 0.8503842721244773
# mean_squared_error: 1.3287507418397622
# mean_absolute_error: 0.8438476755687436
# root_mean_squared_error: 1.15271451011938

# %%
DTR=DecisionTreeRegressor()
DTR.fit(x_train,y_train)
pred_DTR=DTR.predict(x_test)
print('r2_score:',r2_score(y_test,pred_DTR))
print('mean_squared_error:',mean_squared_error(y_test,pred_DTR))
print('mean_absolute_error:',mean_absolute_error(y_test,pred_DTR))
print('root_mean_squared_error:',np.sqrt(mean_squared_error(y_test,pred_DTR)))
# Out:
# r2_score: 0.7402676657503503
# mean_squared_error: 2.306706231454006
# mean_absolute_error: 1.0944609297725025
# root_mean_squared_error: 1.518784458523989

# %%
svr=SVR()
svr.fit(x_train,y_train)
pred_svr=svr.predict(x_test)
print('r2_score:',r2_score(y_test,pred_svr))
print('mean_squared_error:',mean_squared_error(y_test,pred_svr))
print('mean_absolute_error:',mean_absolute_error(y_test,pred_svr))
print('root_mean_squared_error:',np.sqrt(mean_squared_error(y_test,pred_svr)))
# Out:
# r2_score: 0.872786361298739
# mean_squared_error: 1.1297957721200944
# mean_absolute_error: 0.769171346809487
# root_mean_squared_error: 1.0629185162184798

# %% [markdown]
# From the above model building, we can assume that ExtraTreesRegressor is best model. But let's proceed with cross validation score to find out the best model.

# %% [markdown]
# # Cross_Val_Score

# %%
from sklearn.model_selection import cross_val_score

# %%
score=cross_val_score(LR,x,y)
print(score)
print(score.mean())
print('Difference between r2_score and cross_val_score is',(r2_score(y_test,pred_LR)-score.mean())*100)
# Out:
# [0.75173858 0.6855099  0.70173453 0.75157088 0.68358258]
# 0.7148272970776623
# Difference between r2_score and cross_val_score is 8.071254670562155

# %%
score1=cross_val_score(Ls,x,y)
print(score1)
print(score1.mean())
print('Difference between cross validation score and r2 score is',(r2_score(y_test,pred_Ls)-score1.mean())*100)
# Out:
# [0.4929044  0.47299483 0.56854171 0.42079738 0.52789789]
# 0.4966272403537687
# Difference between cross validation score and r2 score is 5.446461194288521

# %%
score2=cross_val_score(Rd,x,y)
print(score2)
print(score2.mean())
print('Difference between cross validation score and r2 score is',(r2_score(y_test,pred_Rd)-score2.mean())*100)
# Out:
# [0.75188772 0.68549455 0.70169748 0.75162762 0.68361279]
# 0.7148640325526393
# Difference between cross validation score and r2 score is 8.066292717957502

# %%
score3=cross_val_score(GBR,x,y)
print(score3)
print(score3.mean())
print('Difference between cross validation score and r2 score is',(r2_score(y_test,pred_GBR)-score3.mean())*100)
# Out:
# [0.73532186 0.65776419 0.69561677 0.76792507 0.67741191]
# 0.7068079614939972
# Difference between cross validation score and r2 score is 14.099232115341053

# %%
score5=cross_val_score(ABR,x,y)
print(score5)
print(score5.mean())
print('Difference between cross validation score and r2 score is',(r2_score(y_test,pred_ABR)-score5.mean())*100)
# Out:
# [0.70985376 0.62320756 0.65026632 0.70248036 0.62593396]
# 0.6623483920278179
# Difference between cross validation score and r2 score is 10.800808895316338

# %%
score6=cross_val_score(ETR,x,y)
print(score6)
print(score6.mean())
print('Difference between cross validation score and r2 score is',(r2_score(y_test,pred_ETR)-score6.mean())*100)
# Out:
# [0.72978748 0.66075607 0.70042124 0.74748739 0.6691801 ]
# 0.7015264561915613
# Difference between cross validation score and r2 score is 21.027087098781916

# %%
score7=cross_val_score(DTR,x,y)
print(score7)
print(score7.mean())
print('Difference between cross validation score and r2 score is',(r2_score(y_test,pred_DTR)-score7.mean())*100)
# Out:
# [0.43534481 0.43886168 0.34371868 0.50774147 0.4523138 ]
# 0.43559608770813074
# Difference between cross validation score and r2 score is 30.467157804221955

# %%
score8=cross_val_score(KNN,x,y)
print(score8)
print(score8.mean())
print('Difference between cross validation score and r2 score is',(r2_score(y_test,pred_KNN)-score8.mean())*100)
# Out:
# [0.60572404 0.43314867 0.52073489 0.62117543 0.58379321]
# 0.5529152471097152
# Difference between cross validation score and r2 score is 29.746902501476214

# %%
score9=cross_val_score(svr,x,y)
print(score9)
print(score9.mean())
print('Difference between cross validation score and r2 score is',(r2_score(y_test,pred_svr)-score9.mean())*100)
# Out:
# [0.70414187 0.59327694 0.67478423 0.75862815 0.67251842]
# 0.6806699215339945
# Difference between cross validation score and r2 score is 19.211643976474445

# %% [markdown]
# After analysing the difference between cross validation score and r2 score we can make sure that Lasso is our best model as difference is less.

# %% [markdown]
# # Hypertuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
Ls.get_params()
# Out:
# {'alpha': 1.0,
#  'copy_X': True,
#  'fit_intercept': True,
#  'max_iter': 1000,
#  'positive': False,
#  'precompute': False,
#  'random_state': None,
#  'selection': 'cyclic',
#  'tol': 0.0001,
#  'warm_start': False}

# %%
params={'alpha':[1.0,2.0,3.0,4.0], 'copy_X':[True,False],
       'fit_intercept':[True,False],'tol':[0.001,0.01,0.1,0.0001],
       'max_iter':[500,1000,1500,2000],
       
       }

# %%
gscv=GridSearchCV(Ls,params,cv=5)

# %%
gscv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [1.0, 2.0, 3.0, 4.0], 'copy_X': [True, False],
#                          'fit_intercept': [True, False],
#                          'max_iter': [500, 1000, 1500, 2000],
#                          'tol': [0.001, 0.01, 0.1, 0.0001]})

# %%
gscv.best_params_
# Out:
# {'alpha': 1.0,
#  'copy_X': True,
#  'fit_intercept': True,
#  'max_iter': 500,
#  'tol': 0.001}

# %%
model=Lasso(alpha=1.0,copy_X=True,fit_intercept=True,max_iter=500,tol=0.001)
model.fit(x_train,y_train)
pred_m=model.predict(x_test)
print('R2_score:',r2_score(y_test,pred_m))
print('Mean_squared_error:',mean_squared_error(y_test,pred_m))
print('Mean_absolute_error:',mean_absolute_error(y_test,pred_m))
print('Root_mean_squared_error:',np.sqrt(mean_squared_error(y_test,pred_m)))
# Out:
# R2_score: 0.5510918522966539
# Mean_squared_error: 3.9867936529707624
# Mean_absolute_error: 1.5963729509185514
# Root_mean_squared_error: 1.9966956836159993

# %% [markdown]
# # Saving model

# %%
import pickle

# %%
filename='Next_Tmax.pkl'
pickle.dump(model,open(filename,'wb'))

# %%
loaded_model=pickle.load(open('Next_Tmax.pkl','rb'))
result=loaded_model.score(x_test,y_test)
print('Result=',result*100)
# Out:
# Result= 55.10918522966539

# %%
conclusion=pd.DataFrame([loaded_model.predict(x_test)[:],y_test[:]],index=['Predicted','Original'])
conclusion
# Out:
#                 0          1          2          3          4          5     \
# Predicted  31.196244  33.339248  29.482767  27.885393  32.967866  30.730471
# Original   31.800000  35.300000  27.100000  28.100000  34.700000  31.000000
#
#                 6          7         8          9     ...       2012  \
# Predicted  28.457789  32.278794  30.07069  29.544255  ...  31.868592
# Original   28.700000  34.000000  25.90000  25.500000  ...  32.700000
#
#                 2013       2014       2015       2016       2017       2018  \
# Predicted  29.960922  27.573612  31.878416  32.102797  29.519391  31.731682
# Original   30.400000  26.600000  33.700000  33.800000  26.600000  32.500000
#
#                 2019       2020       2021
# Predicted  31.010488  30.320605  30.006712
# Original   35.500000  31.200000  29.700000
#
# [2 rows x 2022 columns]

# %% [markdown]
# # Predicting Next_Tmin:

# %%
x1=df1.drop('Next_Tmin',axis=1)
y1=df1['Next_Tmin']

# %%
cor['Next_Tmin'].sort_values(ascending=False)
# Out:
# Next_Tmin           1.000000
# LDAPS_Tmin_lapse    0.875382
# Present_Tmin        0.785946
# Present_Tmax        0.615950
# Next_Tmax           0.580951
# LDAPS_Tmax_lapse    0.553227
# LDAPS_RHmin         0.134518
# station             0.129110
# Solar radiation     0.083207
# LDAPS_CC2           0.078871
# LDAPS_PPT3          0.023274
# LDAPS_CC1           0.008400
# LDAPS_PPT2          0.004340
# LDAPS_CC3           0.000194
# LDAPS_WS           -0.013668
# LDAPS_PPT1         -0.029752
# lon                -0.041574
# LDAPS_CC4          -0.041994
# LDAPS_LH           -0.046540
# lat                -0.076705
# LDAPS_RHmax        -0.097490
# LDAPS_PPT4         -0.106821
# Slope              -0.136838
# DEM                -0.237683
# Name: Next_Tmin, dtype: float64

# %%
plt.figure(figsize=(22,7))
cor['Next_Tmin'].sort_values(ascending=False).drop(['Next_Tmin']).plot(kind='bar',color='m')
plt.xlabel('Features')
plt.ylabel('Target')
plt.title('Correlation betwen target and features')
plt.show()

# %% [markdown]
# LDAPS_CC3 and LDAPS_PPT2 are least correlated with the target.

# %% [markdown]
# # Model Building

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
maxAccu=0
maxRs=0

for i in range(1,200):
    x1_train,x1_test,y1_train,y1_test=train_test_split(x1,y1,test_size=0.3,random_state=i)
    LR=LinearRegression()
    LR.fit(x1_train,y1_train)
    pred_LR=LR.predict(x1_test)
    acc=r2_score(y1_test,pred_LR)
    if acc>maxAccu:
        maxAccu=acc
        maxRs=i
print('Best r2 score is:',maxAccu,'at random state:',maxRs)
# Out:
# Best r2 score is: 0.8500889020570102 at random state: 176

# %%
from sklearn.linear_model import Lasso, Ridge
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor, AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR 
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.ensemble import ExtraTreesRegressor

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
LR=LinearRegression()
LR.fit(x1_train,y1_train)
pred_LR=LR.predict(x1_test)
print('r2_score:',r2_score(y1_test,pred_LR))
print('mean_squared_error:',mean_squared_error(y1_test,pred_LR))
print('mean_absolute_error:',mean_absolute_error(y1_test,pred_LR))
print('root_mean_squared_error:',np.sqrt(mean_squared_error(y1_test,pred_LR)))
# Out:
# r2_score: 0.8401221846868332
# mean_squared_error: 0.9045398958026487
# mean_absolute_error: 0.7581620617100702
# root_mean_squared_error: 0.9510730233807753

# %%
Ls=Lasso()
Ls.fit(x1_train,y1_train)
pred_Ls=Ls.predict(x1_test)
print('r2_score:',r2_score(y1_test,pred_Ls))
print('mean_squared_error:',mean_squared_error(y1_test,pred_Ls))
print('mean_absolute_error:',mean_absolute_error(y1_test,pred_Ls))
print('root_mean_squared_error:',np.sqrt(mean_squared_error(y1_test,pred_Ls)))
# Out:
# r2_score: 0.7781557848497861
# mean_squared_error: 1.2551268783810365
# mean_absolute_error: 0.8939453318178736
# root_mean_squared_error: 1.1203244522820326

# %%
Rd=Ridge()
Rd.fit(x1_train,y1_train)
pred_Rd=Rd.predict(x1_test)
print('r2_score:',r2_score(y1_test,pred_Rd))
print('mean_squared_error:',mean_squared_error(y1_test,pred_Rd))
print('mean_absolute_error:',mean_absolute_error(y1_test,pred_Rd))
print('root_mean_squared_error:',np.sqrt(mean_squared_error(y1_test,pred_Rd)))
# Out:
# r2_score: 0.8401113832306671
# mean_squared_error: 0.904601007145807
# mean_absolute_error: 0.7581751407642588
# root_mean_squared_error: 0.9511051504149303

# %%
RFR=RandomForestRegressor()
RFR.fit(x1_train,y1_train)
pred_RFR=RFR.predict(x1_test)
print('r2_score:',r2_score(y1_test,pred_RFR))
print('mean_squared_error:',mean_squared_error(y1_test,pred_RFR))
print('mean_absolute_error:',mean_absolute_error(y1_test,pred_RFR))
print('root_mean_squared_error:',np.sqrt(mean_squared_error(y1_test,pred_RFR)))
# Out:
# r2_score: 0.9010994389032732
# mean_squared_error: 0.5595491973293768
# mean_absolute_error: 0.5801112759643916
# root_mean_squared_error: 0.7480302115084503

# %%
ETR=ExtraTreesRegressor()
ETR.fit(x1_train,y1_train)
pred_ETR=ETR.predict(x1_test)
print('r2_score:',r2_score(y1_test,pred_ETR))
print('mean_squared_error:',mean_squared_error(y1_test,pred_ETR))
print('mean_absolute_error:',mean_absolute_error(y1_test,pred_ETR))
print('root_mean_squared_error:',np.sqrt(mean_squared_error(y1_test,pred_ETR)))
# Out:
# r2_score: 0.9121658434508007
# mean_squared_error: 0.49693885707220586
# mean_absolute_error: 0.541738377843719
# root_mean_squared_error: 0.7049389030775688

# %%
ABR=AdaBoostRegressor()
ABR.fit(x1_train,y1_train)
pred_ABR=ABR.predict(x1_test)
print('r2_score:',r2_score(y1_test,pred_ABR))
print('mean_squared_error:',mean_squared_error(y1_test,pred_ABR))
print('mean_absolute_error:',mean_absolute_error(y1_test,pred_ABR))
print('root_mean_squared_error:',np.sqrt(mean_squared_error(y1_test,pred_ABR)))
# Out:
# r2_score: 0.8004824169408591
# mean_squared_error: 1.1288096064960982
# mean_absolute_error: 0.8639746982474417
# root_mean_squared_error: 1.0624545197306556

# %%
GBR=GradientBoostingRegressor()
GBR.fit(x1_train,y1_train)
pred_GBR=GBR.predict(x1_test)
print('r2_score:',r2_score(y1_test,pred_GBR))
print('mean_squared_error:',mean_squared_error(y1_test,pred_GBR))
print('mean_absolute_error:',mean_absolute_error(y1_test,pred_GBR))
print('root_mean_squared_error:',np.sqrt(mean_squared_error(y1_test,pred_GBR)))
# Out:
# r2_score: 0.8934978331921196
# mean_squared_error: 0.6025567629783765
# mean_absolute_error: 0.6101401355831124
# root_mean_squared_error: 0.7762452982004957

# %%
KNN=KNN()
KNN.fit(x1_train,y1_train)
pred_KNN=KNN.predict(x1_test)
print('r2_score:',r2_score(y1_test,pred_KNN))
print('mean_squared_error:',mean_squared_error(y1_test,pred_KNN))
print('mean_absolute_error:',mean_absolute_error(y1_test,pred_KNN))
print('root_mean_squared_error:',np.sqrt(mean_squared_error(y1_test,pred_KNN)))
# Out:
# r2_score: 0.5013969678549814
# mean_squared_error: 2.8209438180019784
# mean_absolute_error: 1.3061622156280912
# root_mean_squared_error: 1.679566556585948

# %%
DTR=DecisionTreeRegressor()
DTR.fit(x1_train,y1_train)
pred_DTR=DTR.predict(x1_test)
print('r2_score:',r2_score(y1_test,pred_DTR))
print('mean_squared_error:',mean_squared_error(y1_test,pred_DTR))
print('mean_absolute_error:',mean_absolute_error(y1_test,pred_DTR))
print('root_mean_squared_error:',np.sqrt(mean_squared_error(y1_test,pred_DTR)))
# Out:
# r2_score: 0.7838059023829836
# mean_squared_error: 1.2231602373887243
# mean_absolute_error: 0.837141444114738
# root_mean_squared_error: 1.1059657487412187

# %%
svr=SVR()
svr.fit(x1_train,y1_train)
pred_svr=svr.predict(x1_test)
print('r2_score:',r2_score(y1_test,pred_svr))
print('mean_squared_error:',mean_squared_error(y1_test,pred_svr))
print('mean_absolute_error:',mean_absolute_error(y1_test,pred_svr))
print('root_mean_squared_error:',np.sqrt(mean_squared_error(y1_test,pred_svr)))
# Out:
# r2_score: 0.10942029085427707
# mean_squared_error: 5.038628253311408
# mean_absolute_error: 1.7980600456301838
# root_mean_squared_error: 2.244688899003915

# %% [markdown]
# From the above model building, we can assume that ExtraTreesRegressor is best model. But let's proceed with cross validation score to find out the best model.

# %% [markdown]
# # Cross_Val_Score

# %%
from sklearn.model_selection import cross_val_score

# %%
score=cross_val_score(LR,x1,y1)
print(score)
print(score.mean())
print('Difference between cross validation score and r2 score is',(r2_score(y1_test,pred_LR)-score.mean())*100)
# Out:
# [0.74966617 0.68231362 0.79943012 0.86210388 0.86616433]
# 0.7919356225771641
# Difference between cross validation score and r2 score is 4.8186562109669095

# %%
score1=cross_val_score(Ls,x1,y1)
print(score1)
print(score1.mean())
print('Difference between cross validation score and r2 score is',(r2_score(y1_test,pred_Ls)-score1.mean())*100)
# Out:
# [0.70236208 0.6383587  0.75159529 0.75752891 0.82168049]
# 0.7343050937994173
# Difference between cross validation score and r2 score is 4.385069105036877

# %%
score2=cross_val_score(Rd,x1,y1)
print(score2)
print(score2.mean())
print('Difference between cross validation score and r2 score is',(r2_score(y1_test,pred_Rd)-score2.mean())*100)
# Out:
# [0.74976857 0.68250006 0.79954192 0.86217242 0.86631011]
# 0.7920586157054572
# Difference between cross validation score and r2 score is 4.805276752520992

# %%
score3=cross_val_score(RFR,x1,y1)
print(score3)
print(score3.mean())
print('Difference between cross validation score and r2 score is',(r2_score(y1_test,pred_RFR)-score3.mean())*100)
# Out:
# [0.7362471  0.69785746 0.80674708 0.8753564  0.85459589]
# 0.7941607875077457
# Difference between cross validation score and r2 score is 10.693865139552749

# %%
score4=cross_val_score(GBR,x1,y1)
print(score4)
print(score4.mean())
print('Difference between cross validation score and r2 score is',(r2_score(y1_test,pred_GBR)-score4.mean())*100)
# Out:
# [0.74335279 0.69790095 0.81969654 0.88166352 0.882899  ]
# 0.8051025575733313
# Difference between cross validation score and r2 score is 8.839527561878835

# %%
score5=cross_val_score(ABR,x1,y1)
print(score5)
print(score5.mean())
print('Difference between cross validation score and r2 score is',(r2_score(y1_test,pred_ABR)-score5.mean())*100)
# Out:
# [0.69041929 0.61314726 0.76467702 0.82690357 0.83511637]
# 0.7460527036345248
# Difference between cross validation score and r2 score is 5.442971330633428

# %%
score6=cross_val_score(ETR,x1,y1)
print(score6)
print(score6.mean())
print('Difference between cross validation score and r2 score is',(r2_score(y1_test,pred_ETR)-score6.mean())*100)
# Out:
# [0.7449079  0.6959863  0.81066726 0.87224659 0.87278174]
# 0.799317957902978
# Difference between cross validation score and r2 score is 11.284788554782265

# %%
score7=cross_val_score(DTR,x1,y1)
print(score7)
print(score7.mean())
print('Difference between cross validation score and r2 score is',(r2_score(y1_test,pred_DTR)-score7.mean())*100)
# Out:
# [0.51507749 0.46504585 0.63072432 0.75918549 0.70158703]
# 0.6143240358827111
# Difference between cross validation score and r2 score is 16.948186650027253

# %%
score8=cross_val_score(KNN,x1,y1)
print(score8)
print(score8.mean())
print('Difference between cross validation score and r2 score is',(r2_score(y1_test,pred_KNN)-score8.mean())*100)
# Out:
# [-0.02335253 -0.46364169  0.13795479  0.26762599  0.34037552]
# 0.05179241419016427
# Difference between cross validation score and r2 score is 44.96045536648172

# %%
score9=cross_val_score(svr,x1,y1)
print(score9)
print(score9.mean())
print('Difference between cross validation score and r2 score is',(r2_score(y1_test,pred_svr)-score9.mean())*100)
# Out:
# [-0.04930258 -0.42782075  0.00796437  0.00273278  0.12313138]
# -0.06865895995701117
# Difference between cross validation score and r2 score is 17.807925081128822

# %% [markdown]
# After analysing the difference between cross validation score and r2 score we can make sure that Lasso is our best model as difference is less.

# %% [markdown]
# # Hypertuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
params={'alpha':[1.0,2.0,3.0,4.0], 'copy_X':[True,False],
       'fit_intercept':[True,False],'tol':[0.001,0.01,0.1,0.0001],
       'max_iter':[500,1000,1500,2000],
       
       }

# %%
gscv=GridSearchCV(Ls,params,cv=5)

# %%
gscv.fit(x1_train,y1_train)
# Out:
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [1.0, 2.0, 3.0, 4.0], 'copy_X': [True, False],
#                          'fit_intercept': [True, False],
#                          'max_iter': [500, 1000, 1500, 2000],
#                          'tol': [0.001, 0.01, 0.1, 0.0001]})

# %%
gscv.best_params_
# Out:
# {'alpha': 1.0,
#  'copy_X': True,
#  'fit_intercept': False,
#  'max_iter': 1500,
#  'tol': 0.001}

# %%
model1=Lasso(alpha=1.0,copy_X=True,fit_intercept=False,max_iter=1500,tol=0.001)
model1.fit(x1_train,y1_train)
pred_m=model1.predict(x1_test)
print('R2_score:',r2_score(y1_test,pred_m))
print('Mean_squared_error:',mean_squared_error(y1_test,pred_m))
print('Mean_absolute_error:',mean_absolute_error(y1_test,pred_m))
print('Root_mean_squared_error:',np.sqrt(mean_squared_error(y1_test,pred_m)))
# Out:
# R2_score: 0.7867505050084509
# Mean_squared_error: 1.2065005742152994
# Mean_absolute_error: 0.8729653618495087
# Root_mean_squared_error: 1.0984082001766462

# %% [markdown]
# # Saving model

# %%
import pickle

# %%
filename='Next_Tmin.pkl'
pickle.dump(model1,open(filename,'wb'))

# %%
loaded_model1=pickle.load(open('Next_Tmin.pkl','rb'))
result=loaded_model1.score(x1_test,y1_test)
print('Result=',result*100)
# Out:
# Result= 78.67505050084509

# %%
conclusion=pd.DataFrame([loaded_model1.predict(x1_test)[:],y_test[:]],index=['Predicted','Original'])
conclusion
# Out:
#                 0          1         2          3          4          5     \
# Predicted  23.382855  25.623922  22.82876  21.460386  25.343364  22.714654
# Original   31.800000  35.300000  27.10000  28.100000  34.700000  31.000000
#
#                 6          7          8          9     ...      2012  \
# Predicted  22.215158  23.700202  23.919913  23.106629  ...  24.79345
# Original   28.700000  34.000000  25.900000  25.500000  ...  32.70000
#
#                2013       2014       2015       2016       2017       2018  \
# Predicted  21.27953  21.025068  24.303825  23.980259  23.578456  24.627698
# Original   30.40000  26.600000  33.700000  33.800000  26.600000  32.500000
#
#                 2019       2020       2021
# Predicted  24.294569  24.871667  23.199688
# Original   35.500000  31.200000  29.700000
#
# [2 rows x 2022 columns]
