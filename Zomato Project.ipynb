# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('zomato.csv')

# %%
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.tail()
# Out:
#       Restaurant ID           Restaurant Name  Country Code       City  \
# 9546        5915730              NamlÛ± Gurme           208  ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208  ÛÁstanbul
# 9548        5915807                     Huqqa           208  ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208  ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208  ÛÁstanbul
#
#                                                 Address     Locality  \
# 9546  Kemankeô Karamustafa Paôa Mahallesi, RÛ±htÛ±...     Karakí_y
# 9547  Koôuyolu Mahallesi, Muhittin íìstí_ndaÛô Cadd...    Koôuyolu
# 9548  Kuruí_eôme Mahallesi, Muallim Naci Caddesi, N...  Kuruí_eôme
# 9549  Kuruí_eôme Mahallesi, Muallim Naci Caddesi, N...  Kuruí_eôme
# 9550  CafeaÛôa Mahallesi, BademaltÛ± Sokak, No 21/B,...         Moda
#
#             Locality Verbose  Longitude   Latitude  \
# 9546     Karakí_y, ÛÁstanbul  28.977392  41.022793
# ...

# %%
df.sample()
# Out:
#       Restaurant ID Restaurant Name  Country Code       City  \
# 6623            978       Bal Gopal             1  New Delhi
#
#                                                 Address        Locality  \
# 6623  46, DDA Market, Opposite Surya Continental, Ra...  Rajouri Garden
#
#                Locality Verbose  Longitude   Latitude               Cuisines  \
# 6623  Rajouri Garden, New Delhi  77.120461  28.638394  North Indian, Mughlai
#
#       ...            Currency Has Table booking Has Online delivery  \
# 6623  ...  Indian Rupees(Rs.)                No                 Yes
#
#      Is delivering now Switch to order menu Price range  Aggregate rating  \
# 6623                No                   No           2               3.4
#
#       Rating color Rating text Votes
# 6623        Orange     Average    49
#
# [1 rows x 21 columns]

# %% [markdown]
# # Exploratory Data Analysis(EDA)

# %%
df.shape
# Out:
# (9551, 21)

# %% [markdown]
# Dataset has 9551 rows and 21 columns

# %%
df.columns
# Out:
# Index(['Restaurant ID', 'Restaurant Name', 'Country Code', 'City', 'Address',
#        'Locality', 'Locality Verbose', 'Longitude', 'Latitude', 'Cuisines',
#        'Average Cost for two', 'Currency', 'Has Table booking',
#        'Has Online delivery', 'Is delivering now', 'Switch to order menu',
#        'Price range', 'Aggregate rating', 'Rating color', 'Rating text',
#        'Votes'],
#       dtype='object')

# %%
df.columns.to_list()
# Out:
# ['Restaurant ID',
#  'Restaurant Name',
#  'Country Code',
#  'City',
#  'Address',
#  'Locality',
#  'Locality Verbose',
#  'Longitude',
#  'Latitude',
#  'Cuisines',
#  'Average Cost for two',
#  'Currency',
#  'Has Table booking',
#  'Has Online delivery',
#  'Is delivering now',
#  'Switch to order menu',
#  'Price range',
#  'Aggregate rating',
#  'Rating color',
#  'Rating text',
#  'Votes']

# %%
df.dtypes
# Out:
# Restaurant ID             int64
# Restaurant Name          object
# Country Code              int64
# City                     object
# Address                  object
# Locality                 object
# Locality Verbose         object
# Longitude               float64
# Latitude                float64
# Cuisines                 object
# Average Cost for two      int64
# Currency                 object
# Has Table booking        object
# Has Online delivery      object
# Is delivering now        object
# Switch to order menu     object
# Price range               int64
# Aggregate rating        float64
# Rating color             object
# Rating text              object
# Votes                     int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                9
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %% [markdown]
# There are 9 null values present in 'Cuisines'. Let us drop them.

# %%
df=df.dropna()

# %%
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730              NamlÛ± Gurme           208         ÛÁstanbul
# 9547        5908749             Ceviz AÛôacÛ±           208         ÛÁstanbul
# 9548        5915807                     Huqqa           208         ÛÁstanbul
# 9549        5916112              Aôôk Kahve           208         ÛÁstanbul
# 9550        5927402  Walter's Coffee Roastery           208         ÛÁstanbul
#
# ...

# %%
df.isnull().sum()
# Out:
# Restaurant ID           0
# Restaurant Name         0
# Country Code            0
# City                    0
# Address                 0
# Locality                0
# Locality Verbose        0
# Longitude               0
# Latitude                0
# Cuisines                0
# Average Cost for two    0
# Currency                0
# Has Table booking       0
# Has Online delivery     0
# Is delivering now       0
# Switch to order menu    0
# Price range             0
# Aggregate rating        0
# Rating color            0
# Rating text             0
# Votes                   0
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %% [markdown]
# There are no null values in the dataset now.

# %%
for i in df.columns:
    print(df[i].value_counts())
    print('/n')
# Out:
# 6317637     1
# 18336474    1
# 18382047    1
# 18441566    1
# 18441669    1
#            ..
# 18451576    1
# 580         1
# 308703      1
# 60          1
# 5927402     1
# Name: Restaurant ID, Length: 9542, dtype: int64
# /n
# Cafe Coffee Day             83
# Domino's Pizza              79
# Subway                      63
# Green Chick Chop            51
# McDonald's                  48
#                             ..
# The Town House Cafe          1
# The G.T. Road                1
# The Darzi Bar & Kitchen      1
# Smoke On Water               1
# Walter's Coffee Roastery     1
# Name: Restaurant Name, Length: 7437, dtype: int64
# /n
# 1      8652
# 216     425
# 215      80
# 30       60
# 214      60
# 189      60
# 148      40
# 208      34
# 14       24
# 162      22
# 94       21
# 184      20
# 166      20
# 191      20
# 37        4
# Name: Country Code, dtype: int64
# /n
# New Delhi         5473
# Gurgaon           1118
# Noida             1080
# ...

# %% [markdown]
# As restaurant id is different to each restaurant, we can make it as index

# %%
df.set_index('Restaurant ID',inplace=True)

# %%
df
# Out:
#                         Restaurant Name  Country Code              City  \
# Restaurant ID
# 6317637                Le Petit Souffle           162       Makati City
# 6304287                Izakaya Kikufuji           162       Makati City
# 6300002          Heat - Edsa Shangri-La           162  Mandaluyong City
# 6318506                            Ooma           162  Mandaluyong City
# 6314302                     Sambo Kojin           162  Mandaluyong City
# ...                                 ...           ...               ...
# 5915730                    NamlÛ± Gurme           208         ÛÁstanbul
# 5908749                   Ceviz AÛôacÛ±           208         ÛÁstanbul
# 5915807                           Huqqa           208         ÛÁstanbul
# 5916112                    Aôôk Kahve           208         ÛÁstanbul
# 5927402        Walter's Coffee Roastery           208         ÛÁstanbul
#
#                                                          Address  \
# Restaurant ID
# ...

# %%
df.nunique().to_frame('No.of.unique values')
# Out:
#                       No.of.unique values
# Restaurant Name                      7437
# Country Code                           15
# City                                  140
# Address                              8910
# Locality                             1206
# Locality Verbose                     1263
# Longitude                            8111
# Latitude                             8668
# Cuisines                             1825
# Average Cost for two                  140
# Currency                               12
# Has Table booking                       2
# Has Online delivery                     2
# Is delivering now                       2
# Switch to order menu                    1
# Price range                             4
# Aggregate rating                       33
# Rating color                            6
# Rating text                             6
# Votes                                1012

# %%
categorical_col=[]

for i in df.dtypes.index:
    if df[i].dtypes=='object':
        categorical_col.append(i)
print('Categorical columns:',categorical_col)



numerical_col=[]

for i in df.dtypes.index:
    if df[i].dtypes!='object':
        numerical_col.append(i)
print('Numerical columns:',numerical_col)
# Out:
# Categorical columns: ['Restaurant Name', 'City', 'Address', 'Locality', 'Locality Verbose', 'Cuisines', 'Currency', 'Has Table booking', 'Has Online delivery', 'Is delivering now', 'Switch to order menu', 'Rating color', 'Rating text']
# Numerical columns: ['Country Code', 'Longitude', 'Latitude', 'Average Cost for two', 'Price range', 'Aggregate rating', 'Votes']

# %%
df.describe()
# Out:
#        Country Code    Longitude     Latitude  Average Cost for two  \
# count   9542.000000  9542.000000  9542.000000           9542.000000
# mean      18.179208    64.274997    25.848532           1200.326137
# std       56.451600    41.197602    11.010094          16128.743876
# min        1.000000  -157.948486   -41.330428              0.000000
# 25%        1.000000    77.081565    28.478658            250.000000
# 50%        1.000000    77.192031    28.570444            400.000000
# 75%        1.000000    77.282043    28.642711            700.000000
# max      216.000000   174.832089    55.976980         800000.000000
#
#        Price range  Aggregate rating         Votes
# count  9542.000000       9542.000000   9542.000000
# mean      1.804968          2.665238    156.772060
# std       0.905563          1.516588    430.203324
# min       1.000000          0.000000      0.000000
# 25%       1.000000          2.500000      5.000000
# ...

# %% [markdown]
# Analysis:
#
#     1)Count is same for all the columns which means there is no missing data.
#     2) Mean for Country Code, Average cost for two and votes are higher than Median which means they're right skewed.
#     3) Max values are higher than all other distribution data.
#     4) We can also notice the standard deviation, 25%, min, 75% values from the describe method.

# %% [markdown]
# # UniVariate Analysis

# %%
plt.figure(figsize=(25,25))
sns.countplot(x='Currency',data=df)
# Out:
# <Axes: xlabel='Currency', ylabel='count'>

# %% [markdown]
# Indian Rupees are higher in count which means Indians are using Zomato more compared to other countries.

# %%
sns.countplot(x='Has Table booking',data=df)
# Out:
# <Axes: xlabel='Has Table booking', ylabel='count'>

# %% [markdown]
# Most of the restaurants does not have table booking.

# %%
sns.countplot(x='Has Online delivery',data=df)
# Out:
# <Axes: xlabel='Has Online delivery', ylabel='count'>

# %% [markdown]
# Most of the restaurants does not have online delivery.

# %%
sns.countplot(x='Is delivering now',data=df)
# Out:
# <Axes: xlabel='Is delivering now', ylabel='count'>

# %% [markdown]
# Very few restaurants are delivering now.

# %%
sns.countplot(x='Price range',data=df)
# Out:
# <Axes: xlabel='Price range', ylabel='count'>

# %% [markdown]
# Price of food with range 1 is higher and range 4 is lower.

# %%
sns.countplot(x='Rating color',data=df)
# Out:
# <Axes: xlabel='Rating color', ylabel='count'>

# %% [markdown]
# Restaurants with Orange rating colour are higher and with Red rating colour are low in number.

# %%
sns.countplot(x='Rating text',data=df)
# Out:
# <Axes: xlabel='Rating text', ylabel='count'>

# %% [markdown]
# Most of the restaurants are given average rating and very few has got poor rating.

# %% [markdown]
# # Bivariate Analysis

# %%
plt.figure(figsize=(10,10))
sns.lineplot(x='Rating text',y='City',data=df)
# Out:
# <Axes: xlabel='Rating text', ylabel='City'>

# %% [markdown]
# Bhopal and Bangalore has excellent ratings where as Mumbai has poor ratings.

# %%
plt.figure(figsize=(15,15))
sns.scatterplot(x='Has Table booking',y='Average Cost for two',data=df)
# Out:
# <Axes: xlabel='Has Table booking', ylabel='Average Cost for two'>

# %% [markdown]
# When there is no table booking for restaurant, the average cost for two is high.

# %%
sns.barplot(x='Has Online delivery',y='Price range',data=df)
# Out:
# <Axes: xlabel='Has Online delivery', ylabel='Price range'>

# %% [markdown]
# Price Range is high for the restaurants which has online delivery.

# %% [markdown]
# # Multivariate Analysis

# %%
sns.pairplot(df,palette='Set2_r')

# %% [markdown]
# Pairplot gives the plotting information related to all the numerical data.

# %% [markdown]
# # Check for skewness

# %%
plt.figure(figsize=(20,25),facecolor='white')
plotnumber=1

for col in numerical_col:
    if plotnumber<=8:
        plt.subplot(4,4,plotnumber)
        sns.distplot(df[col],color='m')
        plt.xlabel(col,fontsize=15)
        plt.yticks(rotation=0,fontsize=15)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# Here we can observe that Average cost for two and Votes are having right skewness.

# %% [markdown]
# # Checking for Outliers:

# %%
plt.figure(figsize=(24,25),facecolor='white')
plotnumber=1

for col in numerical_col:
    if plotnumber<=8:
        plt.subplot(4,2,plotnumber)
        sns.boxplot(df[col],color='m')
        plt.xlabel(col,fontsize=15)
        plt.yticks(rotation=0,fontsize=15)
    plotnumber+=1
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:2263, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:2273, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %% [markdown]
# # Converting categorical columns into numerical columns

# %%
from sklearn.preprocessing import OrdinalEncoder
OE=OrdinalEncoder()

for i in df.columns:
    if df[i].dtypes=='object':
        df[i]=OE.fit_transform(df[i].values.reshape(-1,1))

# %%
df
# Out:
#                Restaurant Name  Country Code   City  Address  Locality  \
# Restaurant ID
# 6317637                 3743.0           162   73.0   8677.0     171.0
# 6304287                 3168.0           162   73.0   6047.0     592.0
# 6300002                 2893.0           162   75.0   4676.0     308.0
# 6318506                 4700.0           162   75.0   8682.0     860.0
# 6314302                 5515.0           162   75.0   8681.0     860.0
# ...                        ...           ...    ...      ...       ...
# 5915730                 4436.0           208  139.0   5918.0     516.0
# 5908749                 1311.0           208  139.0   5954.0     551.0
# 5915807                 3064.0           208  139.0   5958.0     553.0
# 5916112                  513.0           208  139.0   5959.0     553.0
# 5927402                 7231.0           208  139.0   4250.0     668.0
#
#                Locality Verbose   Longitude   Latitude  Cuisines  \
# Restaurant ID
# ...

# %%
df.describe()
# Out:
#        Restaurant Name  Country Code         City      Address     Locality  \
# count      9542.000000   9542.000000  9542.000000  9542.000000  9542.000000
# mean       3648.654265     18.179208    77.570530  4538.486166   657.080277
# std        2140.178731     56.451600    22.781307  2563.438975   314.889244
# min           0.000000      1.000000     0.000000     0.000000     0.000000
# 25%        1775.250000      1.000000    78.250000  2321.250000   381.000000
# 50%        3590.500000      1.000000    87.000000  4606.500000   694.000000
# 75%        5478.750000      1.000000    87.000000  6740.750000   919.000000
# max        7436.000000    216.000000   139.000000  8909.000000  1205.000000
#
#        Locality Verbose    Longitude     Latitude     Cuisines  \
# count       9542.000000  9542.000000  9542.000000  9542.000000
# mean         676.259694    64.274997    25.848532   989.163173
# std          330.752100    41.197602    11.010094   514.326600
# ...

# %% [markdown]
# # Checking for skewness

# %%
df.skew()
# Out:
# Restaurant Name          0.044859
# Country Code             3.064922
# City                    -1.191599
# Address                 -0.040534
# Locality                -0.253110
# Locality Verbose        -0.182343
# Longitude               -2.819828
# Latitude                -3.081780
# Cuisines                -0.305923
# Average Cost for two    35.461264
# Currency                 2.879234
# Has Table booking        2.319457
# Has Online delivery      1.113168
# Is delivering now       16.665472
# Switch to order menu     0.000000
# Price range              0.889879
# Aggregate rating        -0.953052
# Rating color             0.046227
# Rating text              0.430970
# Votes                    8.813270
# dtype: float64

# %%
df['Country Code']=np.cbrt(df['Country Code'])

# %%
df.skew()
# Out:
# Restaurant Name          0.044859
# Country Code             2.943058
# City                    -1.191599
# Address                 -0.040534
# Locality                -0.253110
# Locality Verbose        -0.182343
# Longitude               -2.819828
# Latitude                -3.081780
# Cuisines                -0.305923
# Average Cost for two    35.461264
# Currency                 2.879234
# Has Table booking        2.319457
# Has Online delivery      1.113168
# Is delivering now       16.665472
# Switch to order menu     0.000000
# Price range              0.889879
# Aggregate rating        -0.953052
# Rating color             0.046227
# Rating text              0.430970
# Votes                    8.813270
# dtype: float64

# %%
df['Average Cost for two']=np.cbrt(df['Average Cost for two'])

# %%
df.skew()
# Out:
# Restaurant Name          0.044859
# Country Code             2.943058
# City                    -1.191599
# Address                 -0.040534
# Locality                -0.253110
# Locality Verbose        -0.182343
# Longitude               -2.819828
# Latitude                -3.081780
# Cuisines                -0.305923
# Average Cost for two     9.661970
# Currency                 2.879234
# Has Table booking        2.319457
# Has Online delivery      1.113168
# Is delivering now       16.665472
# Switch to order menu     0.000000
# Price range              0.889879
# Aggregate rating        -0.953052
# Rating color             0.046227
# Rating text              0.430970
# Votes                    8.813270
# dtype: float64

# %%
df['Is delivering now']=np.cbrt(df['Is delivering now'])

# %%
df.skew()
# Out:
# Restaurant Name          0.044859
# Country Code             2.943058
# City                    -1.191599
# Address                 -0.040534
# Locality                -0.253110
# Locality Verbose        -0.182343
# Longitude               -2.819828
# Latitude                -3.081780
# Cuisines                -0.305923
# Average Cost for two     9.661970
# Currency                 2.879234
# Has Table booking        2.319457
# Has Online delivery      1.113168
# Is delivering now       16.665472
# Switch to order menu     0.000000
# Price range              0.889879
# Aggregate rating        -0.953052
# Rating color             0.046227
# Rating text              0.430970
# Votes                    8.813270
# dtype: float64

# %%
df['Votes']=np.cbrt(df['Votes'])

# %%
df.skew()
# Out:
# Restaurant Name          0.044859
# Country Code             2.943058
# City                    -1.191599
# Address                 -0.040534
# Locality                -0.253110
# Locality Verbose        -0.182343
# Longitude               -2.819828
# Latitude                -3.081780
# Cuisines                -0.305923
# Average Cost for two     9.661970
# Currency                 2.879234
# Has Table booking        2.319457
# Has Online delivery      1.113168
# Is delivering now       16.665472
# Switch to order menu     0.000000
# Price range              0.889879
# Aggregate rating        -0.953052
# Rating color             0.046227
# Rating text              0.430970
# Votes                    1.206261
# dtype: float64

# %%
df['Average Cost for two']=np.sqrt(df['Average Cost for two'])

# %%
df.skew()
# Out:
# Restaurant Name          0.044859
# Country Code             2.943058
# City                    -1.191599
# Address                 -0.040534
# Locality                -0.253110
# Locality Verbose        -0.182343
# Longitude               -2.819828
# Latitude                -3.081780
# Cuisines                -0.305923
# Average Cost for two     2.017396
# Currency                 2.879234
# Has Table booking        2.319457
# Has Online delivery      1.113168
# Is delivering now       16.665472
# Switch to order menu     0.000000
# Price range              0.889879
# Aggregate rating        -0.953052
# Rating color             0.046227
# Rating text              0.430970
# Votes                    1.206261
# dtype: float64

# %%
df['Country Code']=np.cbrt(df['Country Code'])

# %%
df.skew()
# Out:
# Restaurant Name          0.044859
# Country Code             2.879568
# City                    -1.191599
# Address                 -0.040534
# Locality                -0.253110
# Locality Verbose        -0.182343
# Longitude               -2.819828
# Latitude                -3.081780
# Cuisines                -0.305923
# Average Cost for two     2.017396
# Currency                 2.879234
# Has Table booking        2.319457
# Has Online delivery      1.113168
# Is delivering now       16.665472
# Switch to order menu     0.000000
# Price range              0.889879
# Aggregate rating        -0.953052
# Rating color             0.046227
# Rating text              0.430970
# Votes                    1.206261
# dtype: float64

# %% [markdown]
# # Correlation

# %%
cor=df.corr()

# %%
cor
# Out:
#                       Restaurant Name  Country Code      City   Address  \
# Restaurant Name              1.000000      0.020981 -0.001969  0.000623
# Country Code                 0.020981      1.000000 -0.173061 -0.204983
# City                        -0.001969     -0.173061  1.000000 -0.020604
# Address                      0.000623     -0.204983 -0.020604  1.000000
# Locality                     0.003963     -0.119473  0.094836  0.159403
# Locality Verbose             0.003916     -0.116871  0.091571  0.160363
# Longitude                   -0.002419     -0.669810  0.114510  0.183177
# Latitude                     0.010054     -0.090058 -0.004607 -0.037977
# Cuisines                     0.051729     -0.139890  0.026584  0.024633
# Average Cost for two         0.039553     -0.401546  0.018061  0.137085
# Currency                     0.009415     -0.040622 -0.074380  0.067356
# Has Table booking            0.041148     -0.064642 -0.004039  0.006036
# ...

# %%
plt.figure(figsize=(20,20))
sns.heatmap(cor,fmt='.1g',annot=True,cmap='Blues')
# Out:
# <Axes: >

# %%
df.drop('Switch to order menu',axis=1,inplace=True)

# %%
cor=df.corr()

# %%
plt.figure(figsize=(20,20))
sns.heatmap(cor,fmt='.1g',annot=True,cmap='Blues')
# Out:
# <Axes: >

# %% [markdown]
# Analysis:
#
#     1) Locality Verbose and Locality are having very strong correlation with each other.
#     2) Aggregate rating and votes are having strong correlation with each other.
#     3) Most of the data is having positive correlation.

# %%
cor['Average Cost for two'].sort_values(ascending=False)
# Out:
# Average Cost for two    1.000000
# Price range             0.502409
# Longitude               0.444946
# Has Table booking       0.427302
# Votes                   0.228617
# Has Online delivery     0.187809
# Currency                0.177915
# Aggregate rating        0.159633
# Address                 0.137085
# Cuisines                0.082540
# Restaurant Name         0.039553
# Is delivering now       0.024694
# City                    0.018061
# Locality               -0.003819
# Locality Verbose       -0.004042
# Rating color           -0.011861
# Rating text            -0.038437
# Latitude               -0.092869
# Country Code           -0.401546
# Name: Average Cost for two, dtype: float64

# %%
plt.figure(figsize=(22,7))
cor['Average Cost for two'].sort_values(ascending=False).drop(['Average Cost for two']).plot(kind='bar',color='m')
plt.xlabel('Features')
plt.ylabel('Target')
plt.title('Correlation with target and feature')
plt.show()

# %% [markdown]
# Target is having very low correlation with Locality and Locality Verbose.

# %%
x=df.drop('Average Cost for two',axis=1)
y=df['Average Cost for two']

# %% [markdown]
# # Standard Scalarization

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)
x
# Out:
#       Restaurant Name  Country Code      City   Address  Locality  \
# 0            0.044085      3.071675 -0.200637  1.614523 -1.543736
# 1           -0.224598      3.071675 -0.200637  0.588504 -0.206688
# 2           -0.353098      3.071675 -0.112841  0.053647 -1.108639
# 3            0.491268      3.071675 -0.112841  1.616473  0.644450
# 4            0.872097      3.071675 -0.112841  1.616083  0.644450
# ...               ...           ...       ...       ...       ...
# 9537         0.367907      3.264137  2.696627  0.538178 -0.448055
# 9538        -1.092328      3.264137  2.696627  0.552222 -0.336899
# 9539        -0.273194      3.264137  2.696627  0.553783 -0.330547
# 9540        -1.465213      3.264137  2.696627  0.554173 -0.330547
# 9541         1.673941      3.264137  2.696627 -0.112545  0.034680
#
#       Locality Verbose  Longitude  Latitude  Cuisines  Currency  \
# 0            -1.524665   1.377641 -1.024849 -0.134480 -4.360670
# ...

# %% [markdown]
# # Variance Inflation Factor(VIF)

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
VIF=pd.DataFrame()
VIF['VIF Values']=[variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
VIF['Features']=x.columns
VIF
# Out:
#     VIF Values             Features
# 0     1.008189      Restaurant Name
# 1     2.439341         Country Code
# 2     1.080837                 City
# 3     1.104391              Address
# 4   951.399481             Locality
# 5   950.402683     Locality Verbose
# 6     2.269567            Longitude
# 7     1.107399             Latitude
# 8     1.046452             Cuisines
# 9     1.244509             Currency
# 10    1.475025    Has Table booking
# 11    1.182847  Has Online delivery
# 12    1.013938    Is delivering now
# 13    1.988159          Price range
# 14    2.987882     Aggregate rating
# 15    1.222208         Rating color
# 16    1.458941          Rating text
# 17    2.882680                Votes

# %% [markdown]
# Lets drop Locality as it has high VIF value

# %%
x.drop('Locality',axis=1,inplace=True)

# %%
VIF=pd.DataFrame()
VIF['VIF Values']=[variance_inflation_factor(x.values,i) for i in range(len(x.columns))]
VIF['Features']=x.columns
VIF
# Out:
#     VIF Values             Features
# 0     1.008170      Restaurant Name
# 1     2.436991         Country Code
# 2     1.072703                 City
# 3     1.102729              Address
# 4     1.070595     Locality Verbose
# 5     2.269486            Longitude
# 6     1.107399             Latitude
# 7     1.046123             Cuisines
# 8     1.243722             Currency
# 9     1.474980    Has Table booking
# 10    1.182383  Has Online delivery
# 11    1.013937    Is delivering now
# 12    1.986039          Price range
# 13    2.987846     Aggregate rating
# 14    1.221112         Rating color
# 15    1.458907          Rating text
# 16    2.881762                Votes

# %% [markdown]
# We don't have any multicolinearity issue now. Let's proceed further for model building.

# %% [markdown]
# # Model Building

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
from sklearn.model_selection import train_test_split

# %%
maxAccu=0
maxRs=0

for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=i)
    LR=LinearRegression()
    LR.fit(x_train,y_train)
    pred_LR=LR.predict(x_test)
    r2=r2_score(y_test,pred_LR)
    if r2>maxAccu:
        maxAccu=r2
        maxRs=i
print('Best R2 score is:',maxAccu,'at random state:',maxRs)
# Out:
# Best R2 score is: 0.732250391852936 at random state: 96

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=i)

# %%
from sklearn.linear_model import Lasso, Ridge
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor, GradientBoostingRegressor, AdaBoostRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.svm import SVR

# %%
Ls=Lasso()
Ls.fit(x_train,y_train)
pred_Ls=Ls.predict(x_test)
print('r2_score:',r2_score(y_test,pred_Ls))
print('mean_squared_error:',mean_squared_error(y_test,pred_Ls))
print('mean_absolute_error:',mean_absolute_error(y_test,pred_Ls))
print('root_mean_squared_error:',np.sqrt(mean_squared_error(y_test,pred_Ls)))
# Out:
# r2_score: -0.00042117621805193295
# mean_squared_error: 0.24752883776608836
# mean_absolute_error: 0.3343131184505342
# root_mean_squared_error: 0.4975227007545368

# %%
Rd=Ridge()
Rd.fit(x_train,y_train)
pred_Rd=Rd.predict(x_test)
print('r2_score:',r2_score(y_test,pred_Rd))
print('mean_squared_error:',mean_squared_error(y_test,pred_Rd))
print('mean_absolute_error:',mean_absolute_error(y_test,pred_Rd))
print('root_mean_squared_error:',np.sqrt(mean_squared_error(y_test,pred_Rd)))
# Out:
# r2_score: 0.6336313224356105
# mean_squared_error: 0.09064863390261342
# mean_absolute_error: 0.14594352651779127
# root_mean_squared_error: 0.30107911568658063

# %%
ETR=ExtraTreesRegressor()
ETR.fit(x_train,y_train)
pred_ETR=ETR.predict(x_test)
print('r2_score:',r2_score(y_test,pred_ETR))
print('mean_squared_error:',mean_squared_error(y_test,pred_ETR))
print('mean_absolute_error:',mean_absolute_error(y_test,pred_ETR))
print('root_mean_squared_error:',np.sqrt(mean_squared_error(y_test,pred_ETR)))
# Out:
# r2_score: 0.8997289469554999
# mean_squared_error: 0.024809528038495995
# mean_absolute_error: 0.09674875830393623
# root_mean_squared_error: 0.15751040612764605

# %%
ABR=AdaBoostRegressor()
ABR.fit(x_train,y_train)
pred_ABR=ABR.predict(x_test)
print('r2_score:',r2_score(y_test,pred_ABR))
print('mean_squared_error:',mean_squared_error(y_test,pred_ABR))
print('mean_absolute_error:',mean_absolute_error(y_test,pred_ABR))
print('root_mean_squared_error:',np.sqrt(mean_squared_error(y_test,pred_ABR)))
# Out:
# r2_score: 0.8050954591543719
# mean_squared_error: 0.048224183591587685
# mean_absolute_error: 0.14921398604587424
# root_mean_squared_error: 0.21960005371490163

# %%
GBR=GradientBoostingRegressor()
GBR.fit(x_train,y_train)
pred_GBR=GBR.predict(x_test)
print('r2_score:',r2_score(y_test,pred_GBR))
print('mean_squared_error:',mean_squared_error(y_test,pred_GBR))
print('mean_absolute_error:',mean_absolute_error(y_test,pred_GBR))
print('root_mean_squared_error:',np.sqrt(mean_squared_error(y_test,pred_GBR)))
# Out:
# r2_score: 0.901762499878754
# mean_squared_error: 0.02430637696213453
# mean_absolute_error: 0.10635863812217021
# root_mean_squared_error: 0.15590502545503312

# %%
KNN=KNN()
KNN.fit(x_train,y_train)
pred_KNN=KNN.predict(x_test)
print('r2_score:',r2_score(y_test,pred_KNN))
print('mean_squared_error:',mean_squared_error(y_test,pred_KNN))
print('mean_absolute_error:',mean_absolute_error(y_test,pred_KNN))
print('root_mean_squared_error:',np.sqrt(mean_squared_error(y_test,pred_KNN)))
# Out:
# r2_score: 0.8356303077638807
# mean_squared_error: 0.040669110021225974
# mean_absolute_error: 0.1327990278882584
# root_mean_squared_error: 0.2016658375164866

# %%
DTR=DecisionTreeRegressor()
DTR.fit(x_train,y_train)
pred_DTR=DTR.predict(x_test)
print('r2_score:',r2_score(y_test,pred_DTR))
print('mean_squared_error:',mean_squared_error(y_test,pred_DTR))
print('mean_absolute_error:',mean_absolute_error(y_test,pred_DTR))
print('root_mean_squared_error:',np.sqrt(mean_squared_error(y_test,pred_DTR)))
# Out:
# r2_score: 0.7880871487302079
# mean_squared_error: 0.052432458477944664
# mean_absolute_error: 0.12451397537516692
# root_mean_squared_error: 0.22898134962905747

# %%
SVR=SVR()
SVR.fit(x_train,y_train)
pred_SVR=SVR.predict(x_test)
print('r2_score:',r2_score(y_test,pred_SVR))
print('mean_squared_error:',mean_squared_error(y_test,pred_SVR))
print('mean_absolute_error:',mean_absolute_error(y_test,pred_SVR))
print('root_mean_squared_error:',np.sqrt(mean_squared_error(y_test,pred_SVR)))
# Out:
# r2_score: 0.8424323201901456
# mean_squared_error: 0.03898612462430665
# mean_absolute_error: 0.11692852489377215
# root_mean_squared_error: 0.19744904310810588

# %% [markdown]
# From the above model building, we can assume that GradientBoostingRegressor is best model. But let's proceed with cross validation score to find out the best model.

# %% [markdown]
# # Cross_Val_Score

# %%
from sklearn.model_selection import cross_val_score

# %%
score=cross_val_score(LR,x,y)
print(score)
print(score.mean())
print('Difference between r2_score and cross_val_score is',(r2_score(y_test,pred_LR)-score.mean())*100)
# Out:
# [-0.90005297  0.78458573  0.78929913  0.80805401  0.06241342]
# 0.3088598626154106
# Difference between r2_score and cross_val_score is 32.47693376979062

# %%
score1=cross_val_score(Ls,x,y)
print(score1)
print(score1.mean())
print('Difference between cross validation score and r2 score is',(r2_score(y_test,pred_Ls)-score1.mean())*100)
# Out:
# [-0.1423807  -0.17425742 -0.00049893 -0.01483322 -0.00168355]
# -0.06673076491803687
# Difference between cross validation score and r2 score is 6.630958869998493

# %%
score2=cross_val_score(Rd,x,y)
print(score2)
print(score2.mean())
print('Difference between cross validation score and r2 score is',(r2_score(y_test,pred_Rd)-score2.mean())*100)
# Out:
# [-0.89701073  0.78458048  0.78928014  0.80802469  0.06391112]
# 0.3097571408138379
# Difference between cross validation score and r2 score is 32.38741816217726

# %%
score3=cross_val_score(GBR,x,y)
print(score3)
print(score3.mean())
print('Difference between cross validation score and r2 score is',(r2_score(y_test,pred_GBR)-score3.mean())*100)
# Out:
# [-0.06014956  0.82431755  0.83200111  0.85882707  0.1686628 ]
# 0.5247317934836568
# Difference between cross validation score and r2 score is 37.70307063950972

# %%
score5=cross_val_score(ABR,x,y)
print(score5)
print(score5.mean())
print('Difference between cross validation score and r2 score is',(r2_score(y_test,pred_ABR)-score5.mean())*100)
# Out:
# [-0.84079302  0.69335384  0.71295201  0.62741998 -0.06702724]
# 0.22518111459368745
# Difference between cross validation score and r2 score is 57.99143445606845

# %%
score6=cross_val_score(ETR,x,y)
print(score6)
print(score6.mean())
print('Difference between cross validation score and r2 score is',(r2_score(y_test,pred_ETR)-score6.mean())*100)
# Out:
# [-0.97754138  0.83926126  0.84439796  0.87657183  0.146562  ]
# 0.34585033241355434
# Difference between cross validation score and r2 score is 55.38786145419456

# %%
score7=cross_val_score(DTR,x,y)
print(score7)
print(score7.mean())
print('Difference between cross validation score and r2 score is',(r2_score(y_test,pred_DTR)-score7.mean())*100)
# Out:
# [-2.97165842  0.68938284  0.72350721  0.76690217  0.22297721]
# -0.11377779907408474
# Difference between cross validation score and r2 score is 90.18649478042926

# %%
score8=cross_val_score(KNN,x,y)
print(score8)
print(score8.mean())
print('Difference between cross validation score and r2 score is',(r2_score(y_test,pred_KNN)-score8.mean())*100)
# Out:
# [-0.43730777  0.72587756  0.74519075  0.7717098   0.12656214]
# 0.38640649430851787
# Difference between cross validation score and r2 score is 44.92238134553628

# %%
score9=cross_val_score(SVR,x,y)
print(score9)
print(score9.mean())
print('Difference between cross validation score and r2 score is',(r2_score(y_test,pred_SVR)-score9.mean())*100)
# Out:
# [-0.192312    0.80130821  0.81014812  0.82686345  0.11394286]
# 0.47199012715623667
# Difference between cross validation score and r2 score is 37.04421930339089

# %% [markdown]
# After analysing the difference between cross validation score and r2 score we can make sure that Lasso is our best model as difference is less.

# %% [markdown]
# # Hypertuning

# %%
from sklearn.model_selection import GridSearchCV

# %%
Ls.get_params()
# Out:
# {'alpha': 1.0,
#  'copy_X': True,
#  'fit_intercept': True,
#  'max_iter': 1000,
#  'positive': False,
#  'precompute': False,
#  'random_state': None,
#  'selection': 'cyclic',
#  'tol': 0.0001,
#  'warm_start': False}

# %%
params={'alpha':[1.0,2.0,3.0,4.0], 'copy_X':[True,False],
       'fit_intercept':[True,False],'tol':[0.001,0.01,0.1,0.0001],
       'max_iter':[500,1000,1500,2000],
       
       }

# %%
gscv=GridSearchCV(Ls,params,cv=5)

# %%
gscv.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=Lasso(),
#              param_grid={'alpha': [1.0, 2.0, 3.0, 4.0], 'copy_X': [True, False],
#                          'fit_intercept': [True, False],
#                          'max_iter': [500, 1000, 1500, 2000],
#                          'tol': [0.001, 0.01, 0.1, 0.0001]})

# %%
gscv.best_params_
# Out:
# {'alpha': 1.0,
#  'copy_X': True,
#  'fit_intercept': True,
#  'max_iter': 500,
#  'tol': 0.001}

# %%
model=Lasso(alpha=1.0,copy_X=True,fit_intercept=True,max_iter=500,tol=0.001)
model.fit(x_train,y_train)
pred_m=model.predict(x_test)
print('R2_score:',r2_score(y_test,pred_m))
print('Mean_squared_error:',mean_squared_error(y_test,pred_m))
print('Mean_absolute_error:',mean_absolute_error(y_test,pred_m))
print('Root_mean_squared_error:',np.sqrt(mean_squared_error(y_test,pred_m)))
# Out:
# R2_score: -0.00042117621805193295
# Mean_squared_error: 0.24752883776608836
# Mean_absolute_error: 0.3343131184505342
# Root_mean_squared_error: 0.4975227007545368

# %% [markdown]
# # Saving Model

# %%
import pickle

# %%
filename='Zomato.pkl'
pickle.dump(model,open(filename,'wb'))

# %%
loaded_model=pickle.load(open('Zomato.pkl','rb'))
result=loaded_model.score(x_test,y_test)
print('Result',result*100)
# Out:
# Result -0.042117621805193295

# %%
conclusion=pd.DataFrame([loaded_model.predict(x_test)[:],y_test[:]],index=['Predicted','Original'])
conclusion
# Out:
#                0         1         2         3         4         5     \
# Predicted  2.736019  2.736019  2.736019  2.736019  2.736019  2.736019
# Original   2.587340  2.943194  2.305058  2.979772  1.467799  1.709976
#
#                6         7         8         9     ...      2853      2854  \
# Predicted  2.736019  2.736019  2.736019  2.736019  ...  2.736019  2.736019
# Original   2.587340  2.943194  2.714418  2.154435  ...  2.904191  3.212912
#
#                2855      2856      2857      2858      2859      2860  \
# Predicted  2.736019  2.736019  2.736019  2.736019  2.736019  2.736019
# Original   2.817269  2.654675  3.212912  3.549537  3.383363  2.904191
#
#                2861      2862
# Predicted  2.736019  2.736019
# Original   2.979772  3.046831
#
# [2 rows x 2863 columns]

# %% [markdown]
# # Predicting Price range

# %%
x1=df.drop('Price range',axis=1)
y1=df['Price range']

# %%
cor['Price range'].sort_values(ascending=False)
# Out:
# Price range             1.000000
# Votes                   0.519604
# Average Cost for two    0.502409
# Has Table booking       0.502166
# Aggregate rating        0.438356
# Country Code            0.275281
# Rating text             0.163778
# Has Online delivery     0.077887
# Currency                0.075073
# Restaurant Name         0.061676
# Is delivering now       0.010937
# Cuisines               -0.005265
# Address                -0.035257
# Longitude              -0.080257
# City                   -0.104848
# Locality Verbose       -0.112868
# Locality               -0.115026
# Rating color           -0.140953
# Latitude               -0.166735
# Name: Price range, dtype: float64

# %%
plt.figure(figsize=(22,7))
cor['Price range'].sort_values(ascending=False).drop(['Price range']).plot(kind='bar',color='m')
plt.xlabel('Features')
plt.ylabel('Target')
plt.title('Correlation betwen target and features')
plt.show()

# %% [markdown]
# Is delivering now and Cuisines are least correlated with the target.

# %% [markdown]
# # Model Building

# %%
maxAccu=0
maxRs=0

for i in range(1,200):
    x1_train,x1_test,y1_train,y1_test=train_test_split(x1,y1,test_size=0.3,random_state=i)
    LR=LinearRegression()
    LR.fit(x1_train,y1_train)
    pred_LR=LR.predict(x1_test)
    acc=r2_score(y1_test,pred_LR)
    if acc>maxAccu:
        maxAccu=acc
        maxRs=i
print('Best r2 score is:',maxAccu,'at random state:',maxRs)
# Out:
# Best r2 score is: 0.6757615885964776 at random state: 62

# %%
x1_train,x1_test,y1_train,y1_test=train_test_split(x1,y1,test_size=0.3,random_state=i)

# %%
LR=LinearRegression()
LR.fit(x1_train,y1_train)
pred_LR=LR.predict(x1_test)
print('r2_score:',r2_score(y1_test,pred_LR))
print('mean_squared_error:',mean_squared_error(y1_test,pred_LR))
print('mean_absolute_error:',mean_absolute_error(y1_test,pred_LR))
print('root_mean_squared_error:',np.sqrt(mean_squared_error(y1_test,pred_LR)))
# Out:
# r2_score: 0.6455109613137722
# mean_squared_error: 0.29242835503754655
# mean_absolute_error: 0.4024589674205263
# root_mean_squared_error: 0.540766451471933

# %%
Ls=Lasso()
Ls.fit(x1_train,y1_train)
pred_Ls=Ls.predict(x1_test)
print('r2_score:',r2_score(y1_test,pred_Ls))
print('mean_squared_error:',mean_squared_error(y1_test,pred_Ls))
print('mean_absolute_error:',mean_absolute_error(y1_test,pred_Ls))
print('root_mean_squared_error:',np.sqrt(mean_squared_error(y1_test,pred_Ls)))
# Out:
# r2_score: 0.11750605911141887
# mean_squared_error: 0.7279950105680818
# mean_absolute_error: 0.7005695866385548
# root_mean_squared_error: 0.85322623645085

# %%
Rd=Ridge()
Rd.fit(x1_train,y1_train)
pred_Rd=Rd.predict(x1_test)
print('r2_score:',r2_score(y1_test,pred_Rd))
print('mean_squared_error:',mean_squared_error(y1_test,pred_Rd))
print('mean_absolute_error:',mean_absolute_error(y1_test,pred_Rd))
print('root_mean_squared_error:',np.sqrt(mean_squared_error(y1_test,pred_Rd)))
# Out:
# r2_score: 0.6452821964220218
# mean_squared_error: 0.29261706987406966
# mean_absolute_error: 0.4032376468329605
# root_mean_squared_error: 0.5409409116290518

# %%
RFR=RandomForestRegressor()
RFR.fit(x1_train,y1_train)
pred_RFR=RFR.predict(x1_test)
print('r2_score:',r2_score(y1_test,pred_RFR))
print('mean_squared_error:',mean_squared_error(y1_test,pred_RFR))
print('mean_absolute_error:',mean_absolute_error(y1_test,pred_RFR))
print('root_mean_squared_error:',np.sqrt(mean_squared_error(y1_test,pred_RFR)))
# Out:
# r2_score: 0.9841707430793845
# mean_squared_error: 0.01305801606706252
# mean_absolute_error: 0.02992315752706951
# root_mean_squared_error: 0.11427167657412977

# %%
ETR=ExtraTreesRegressor()
ETR.fit(x1_train,y1_train)
pred_ETR=ETR.predict(x1_test)
print('r2_score:',r2_score(y1_test,pred_ETR))
print('mean_squared_error:',mean_squared_error(y1_test,pred_ETR))
print('mean_absolute_error:',mean_absolute_error(y1_test,pred_ETR))
print('root_mean_squared_error:',np.sqrt(mean_squared_error(y1_test,pred_ETR)))
# Out:
# r2_score: 0.9798233721901152
# mean_squared_error: 0.01664428920712539
# mean_absolute_error: 0.04305972755850505
# root_mean_squared_error: 0.12901274823491432

# %%
ABR=AdaBoostRegressor()
ABR.fit(x1_train,y1_train)
pred_ABR=ABR.predict(x1_test)
print('r2_score:',r2_score(y1_test,pred_ABR))
print('mean_squared_error:',mean_squared_error(y1_test,pred_ABR))
print('mean_absolute_error:',mean_absolute_error(y1_test,pred_ABR))
print('root_mean_squared_error:',np.sqrt(mean_squared_error(y1_test,pred_ABR)))
# Out:
# r2_score: 0.9267383938584886
# mean_squared_error: 0.06043563730706445
# mean_absolute_error: 0.1764874360317187
# root_mean_squared_error: 0.24583660693042533

# %%
GBR=GradientBoostingRegressor()
GBR.fit(x1_train,y1_train)
pred_GBR=GBR.predict(x1_test)
print('r2_score:',r2_score(y1_test,pred_GBR))
print('mean_squared_error:',mean_squared_error(y1_test,pred_GBR))
print('mean_absolute_error:',mean_absolute_error(y1_test,pred_GBR))
print('root_mean_squared_error:',np.sqrt(mean_squared_error(y1_test,pred_GBR)))
# Out:
# r2_score: 0.9740962402092735
# mean_squared_error: 0.021368767544868453
# mean_absolute_error: 0.058678001357833756
# root_mean_squared_error: 0.14618059907138312

# %%
DTR=DecisionTreeRegressor()
DTR.fit(x1_train,y1_train)
pred_DTR=DTR.predict(x1_test)
print('r2_score:',r2_score(y1_test,pred_DTR))
print('mean_squared_error:',mean_squared_error(y1_test,pred_DTR))
print('mean_absolute_error:',mean_absolute_error(y1_test,pred_DTR))
print('root_mean_squared_error:',np.sqrt(mean_squared_error(y1_test,pred_DTR)))
# Out:
# r2_score: 0.9724782948329679
# mean_squared_error: 0.022703457911281873
# mean_absolute_error: 0.021306322039818373
# root_mean_squared_error: 0.15067666677784544

# %% [markdown]
# From the above model building, we can assume that RandomForestRegressor is best model. But let's proceed with cross validation score to find out the best model.

# %% [markdown]
# # Cross_Val_Score

# %%
from sklearn.model_selection import cross_val_score

# %%
score=cross_val_score(LR,x1,y1)
print(score)
print(score.mean())
print('Difference between cross validation score and r2 score is',(r2_score(y1_test,pred_LR)-score.mean())*100)
# Out:
# [ 0.11819816  0.67794001  0.69204323  0.74330945 -0.54960956]
# 0.33637625879198624
# Difference between cross validation score and r2 score is 30.913470252178595

# %%
score1=cross_val_score(Ls,x1,y1)
print(score1)
print(score1.mean())
print('Difference between cross validation score and r2 score is',(r2_score(y1_test,pred_Ls)-score1.mean())*100)
# Out:
# [-0.00307637  0.05030966 -0.04304242  0.04040131  0.1119813 ]
# 0.031314699244875045
# Difference between cross validation score and r2 score is 8.619135986654383

# %%
score2=cross_val_score(Rd,x1,y1)
print(score2)
print(score2.mean())
print('Difference between cross validation score and r2 score is',(r2_score(y1_test,pred_Rd)-score2.mean())*100)
# Out:
# [ 0.01295852  0.67669521  0.69030295  0.74167922 -0.53307127]
# 0.31771292591174705
# Difference between cross validation score and r2 score is 32.756927051027475

# %%
score3=cross_val_score(RFR,x1,y1)
print(score3)
print(score3.mean())
print('Difference between cross validation score and r2 score is',(r2_score(y1_test,pred_RFR)-score3.mean())*100)
# Out:
# [0.71120797 0.96584721 0.99972608 0.99871492 0.77736608]
# 0.8905724518013812
# Difference between cross validation score and r2 score is 9.359829127800323

# %%
score4=cross_val_score(GBR,x1,y1)
print(score4)
print(score4.mean())
print('Difference between cross validation score and r2 score is',(r2_score(y1_test,pred_GBR)-score4.mean())*100)
# Out:
# [0.54537191 0.96575643 0.99826336 0.99800487 0.75161545]
# 0.8518024036731939
# Difference between cross validation score and r2 score is 12.229383653607961

# %%
score5=cross_val_score(ABR,x1,y1)
print(score5)
print(score5.mean())
print('Difference between cross validation score and r2 score is',(r2_score(y1_test,pred_ABR)-score5.mean())*100)
# Out:
# [0.46404135 0.90907735 0.88104026 0.90407166 0.71855536]
# 0.775357195675439
# Difference between cross validation score and r2 score is 15.13811981830495

# %%
score6=cross_val_score(ETR,x1,y1)
print(score6)
print(score6.mean())
print('Difference between cross validation score and r2 score is',(r2_score(y1_test,pred_ETR)-score6.mean())*100)
# Out:
# [0.8090766  0.97012642 0.99711601 0.9983198  0.86851522]
# 0.9286308103921768
# Difference between cross validation score and r2 score is 5.11925617979384

# %%
score7=cross_val_score(DTR,x1,y1)
print(score7)
print(score7.mean())
print('Difference between cross validation score and r2 score is',(r2_score(y1_test,pred_DTR)-score7.mean())*100)
# Out:
# [0.03254781 0.94212519 1.         0.99779095 0.8462141 ]
# 0.7637356112634676
# Difference between cross validation score and r2 score is 20.874268356950033

# %% [markdown]
# After analysing the difference between cross validation score and r2 score we can make sure that ExtraTreesRegressor is our best model as difference is less.

# %% [markdown]
# # Hypertuning

# %%
ETR.get_params()
# Out:
# {'bootstrap': False,
#  'ccp_alpha': 0.0,
#  'criterion': 'squared_error',
#  'max_depth': None,
#  'max_features': 1.0,
#  'max_leaf_nodes': None,
#  'max_samples': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_jobs': None,
#  'oob_score': False,
#  'random_state': None,
#  'verbose': 0,
#  'warm_start': False}

# %%
params={'ccp_alpha':[0.0,1.0,2.0,3.0], 'bootstrap':[True,False],
       'max_depth':[1,5,10,100],'min_samples_leaf':[1,5,50,100],
       'warm_start':[True,False],
       
       }

# %%
gscv=GridSearchCV(ETR,params,cv=5)

# %%
gscv.fit(x1_train,y1_train)
# Out:
# GridSearchCV(cv=5, estimator=ExtraTreesRegressor(),
#              param_grid={'bootstrap': [True, False],
#                          'ccp_alpha': [0.0, 1.0, 2.0, 3.0],
#                          'max_depth': [1, 5, 10, 100],
#                          'min_samples_leaf': [1, 5, 50, 100],
#                          'warm_start': [True, False]})

# %%
gscv.best_params_
# Out:
# {'bootstrap': False,
#  'ccp_alpha': 0.0,
#  'max_depth': 100,
#  'min_samples_leaf': 1,
#  'warm_start': True}

# %%
model1=ExtraTreesRegressor(bootstrap=False,ccp_alpha=0.0,max_depth=100,min_samples_leaf=1,warm_start=True)
model1.fit(x1_train,y1_train)
pred_m=model1.predict(x1_test)
print('R2_score:',r2_score(y1_test,pred_m))
print('Mean_squared_error:',mean_squared_error(y1_test,pred_m))
print('Mean_absolute_error:',mean_absolute_error(y1_test,pred_m))
print('Root_mean_squared_error:',np.sqrt(mean_squared_error(y1_test,pred_m)))
# Out:
# R2_score: 0.9793356875745554
# Mean_squared_error: 0.017046594481313307
# Mean_absolute_error: 0.042989870764931874
# Root_mean_squared_error: 0.13056260751575585

# %% [markdown]
# # Saving Model

# %%
filename='Price range.pkl'
pickle.dump(model1,open(filename,'wb'))

# %%
loaded_model1=pickle.load(open('Price range.pkl','rb'))
result=loaded_model1.score(x1_test,y1_test)
print('Result=',result*100)
# Out:
# Result= 97.93356875745553

# %%
conclusion=pd.DataFrame([loaded_model1.predict(x1_test)[:],y_test[:]],index=['Predicted','Original'])
conclusion
# Out:
#               0         1         2         3         4         5        6     \
# Predicted  1.00000  2.000000  1.000000  2.000000  1.000000  2.000000  1.00000
# Original   2.58734  2.943194  2.305058  2.979772  1.467799  1.709976  2.58734
#
#                7         8         9     ...      2853      2854      2855  \
# Predicted  2.000000  1.000000  1.000000  ...  2.000000  3.340000  2.000000
# Original   2.943194  2.714418  2.154435  ...  2.904191  3.212912  2.817269
#
#                2856      2857      2858      2859      2860      2861  \
# Predicted  1.000000  3.020000  2.580000  3.010000  2.040000  2.000000
# Original   2.654675  3.212912  3.549537  3.383363  2.904191  2.979772
#
#                2862
# Predicted  2.000000
# Original   3.046831
#
# [2 rows x 2863 columns]
