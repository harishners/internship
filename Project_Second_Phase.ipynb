# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv("https://raw.githubusercontent.com/FlipRoboTechnologies/ML-Datasets/main/World%20Happiness/happiness_score_dataset.csv")
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.head()
# Out:
#        Country          Region  Happiness Rank  Happiness Score  \
# 0  Switzerland  Western Europe               1            7.587
# 1      Iceland  Western Europe               2            7.561
# 2      Denmark  Western Europe               3            7.527
# 3       Norway  Western Europe               4            7.522
# 4       Canada   North America               5            7.427
#
#    Standard Error  Economy (GDP per Capita)   Family  \
# 0         0.03411                   1.39651  1.34951
# 1         0.04884                   1.30232  1.40223
# 2         0.03328                   1.32548  1.36058
# 3         0.03880                   1.45900  1.33095
# 4         0.03553                   1.32629  1.32261
#
#    Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                   0.94143  0.66557                        0.41978
# 1                   0.94784  0.62877                        0.14145
# ...

# %%
df.tail()
# Out:
#      Country                           Region  Happiness Rank  \
# 153   Rwanda               Sub-Saharan Africa             154
# 154    Benin               Sub-Saharan Africa             155
# 155    Syria  Middle East and Northern Africa             156
# 156  Burundi               Sub-Saharan Africa             157
# 157     Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 153                   0.42864  0.59201                        0.55191
# ...

# %%
df.sample()
# Out:
#   Country         Region  Happiness Rank  Happiness Score  Standard Error  \
# 4  Canada  North America               5            7.427         0.03553
#
#    Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 4                   1.32629  1.32261                   0.90563  0.63297
#
#    Trust (Government Corruption)  Generosity  Dystopia Residual
# 4                        0.32957     0.45811            2.45176

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 158 entries, 0 to 157
# Data columns (total 12 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        158 non-null    object
#  1   Region                         158 non-null    object
#  2   Happiness Rank                 158 non-null    int64
#  3   Happiness Score                158 non-null    float64
#  4   Standard Error                 158 non-null    float64
#  5   Economy (GDP per Capita)       158 non-null    float64
#  6   Family                         158 non-null    float64
#  7   Health (Life Expectancy)       158 non-null    float64
#  8   Freedom                        158 non-null    float64
#  9   Trust (Government Corruption)  158 non-null    float64
#  10  Generosity                     158 non-null    float64
#  11  Dystopia Residual              158 non-null    float64
# ...

# %%
df.shape
# Out:
# (158, 12)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=158, step=1)

# %%
df.isnull()
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0      False   False           False            False           False
# 1      False   False           False            False           False
# 2      False   False           False            False           False
# 3      False   False           False            False           False
# 4      False   False           False            False           False
# ..       ...     ...             ...              ...             ...
# 153    False   False           False            False           False
# 154    False   False           False            False           False
# 155    False   False           False            False           False
# 156    False   False           False            False           False
# 157    False   False           False            False           False
#
#      Economy (GDP per Capita)  Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.dtypes
# Out:
# Country                           object
# Region                            object
# Happiness Rank                     int64
# Happiness Score                  float64
# Standard Error                   float64
# Economy (GDP per Capita)         float64
# Family                           float64
# Health (Life Expectancy)         float64
# Freedom                          float64
# Trust (Government Corruption)    float64
# Generosity                       float64
# Dystopia Residual                float64
# dtype: object

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
df.columns.tolist()
# Out:
# ['Country',
#  'Region',
#  'Happiness Rank',
#  'Happiness Score',
#  'Standard Error',
#  'Economy (GDP per Capita)',
#  'Family',
#  'Health (Life Expectancy)',
#  'Freedom',
#  'Trust (Government Corruption)',
#  'Generosity',
#  'Dystopia Residual']

# %% [markdown]
# Differentiating categorical and numerical columns

# %%
categorical_col=[]

for i in df.dtypes.index:
    if df.dtypes[i]=='object':
        categorical_col.append(i)
print('Categorical col=',categorical_col)

numerical_col=[]

for i in df.dtypes.index:
    if df.dtypes[i]!='object':
        numerical_col.append(i)
print('Numerical col=',numerical_col)
# Out:
# Categorical col= ['Country', 'Region']
# Numerical col= ['Happiness Rank', 'Happiness Score', 'Standard Error', 'Economy (GDP per Capita)', 'Family', 'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)', 'Generosity', 'Dystopia Residual']

# %% [markdown]
# As Categorical columns are not required for our scenario we'll drop Country and Region and also as Happiness Rank is same as count, we'll drop Happiness rank as well.

# %%
df1=df.drop(['Country','Region','Happiness Rank'],axis=1)
df1
# Out:
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# 1              7.561         0.04884                   1.30232  1.40223
# 2              7.527         0.03328                   1.32548  1.36058
# 3              7.522         0.03880                   1.45900  1.33095
# 4              7.427         0.03553                   1.32629  1.32261
# ..               ...             ...                       ...      ...
# 153            3.465         0.03464                   0.22208  0.77370
# 154            3.340         0.03656                   0.28665  0.35386
# 155            3.006         0.05015                   0.66320  0.47489
# 156            2.905         0.08658                   0.01530  0.41587
# 157            2.839         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# ...

# %%
plt.figure(figsize=(10,6),facecolor='white')
plotnumber=1

for col in numerical_col:
    if plotnumber<=9:
        ax=plt.subplot(3,3,plotnumber)
        sns.distplot(df[col],color='m')
        plt.xlabel(col,fontsize=15)
        plt.yticks(rotation=0,fontsize=15)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# From the above distribution we can observe that:
#
#     1) Standard Error and Generosity is right skewed to the distribution.
#     2) All others do not have much skewness

# %%
sns.pairplot(df1,hue="Happiness Score",palette='Dark2')
plt.show()

# %% [markdown]
# The pairplot gives the related between the feature and taget values. On the diagonal we can observe the distribution plots.

# %% [markdown]
# # checking for outliers

# %%
plt.figure(figsize=(10,6),facecolor='white')
plotnumber=1

for col in numerical_col:
    if plotnumber<=9:
        ax=plt.subplot(3,3,plotnumber)
        sns.boxplot(df[col],palette="Set2_r")
        plt.xlabel(col,fontsize=10)
        plt.yticks(rotation=0,fontsize=10)
    plotnumber+=1
plt.tight_layout()

# %% [markdown]
# From the above boxplot, we can observe that outliers are present in Standard Error, Family, Trust and Generosity

# %%
from scipy.stats import zscore

# %%
z=np.abs(zscore(df1))
threshold=3
np.where(z>3)
df2=df1[(z<3).all(axis=1)]
df2
# Out:
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# 1              7.561         0.04884                   1.30232  1.40223
# 2              7.527         0.03328                   1.32548  1.36058
# 3              7.522         0.03880                   1.45900  1.33095
# 4              7.427         0.03553                   1.32629  1.32261
# ..               ...             ...                       ...      ...
# 150            3.655         0.05141                   0.46534  0.77115
# 151            3.587         0.04324                   0.25812  0.85188
# 152            3.575         0.03084                   0.31982  0.30285
# 154            3.340         0.03656                   0.28665  0.35386
# 156            2.905         0.08658                   0.01530  0.41587
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# ...

# %%
df2.shape
# Out:
# (149, 9)

# %%
print('Data Loss Percentage:',((df1.shape[0]-df2.shape[0])/df1.shape[0])*100)
# Out:
# Data Loss Percentage: 5.69620253164557

# %%
from sklearn.preprocessing import OrdinalEncoder
OE=OrdinalEncoder()
for i in df.columns:
    if df[i].dtypes=='object':
        df[i]=OE.fit_transform(df[i].values.reshape(-1,1))
df
# Out:
#      Country  Region  Happiness Rank  Happiness Score  Standard Error  \
# 0      135.0     9.0               1            7.587         0.03411
# 1       58.0     9.0               2            7.561         0.04884
# 2       37.0     9.0               3            7.527         0.03328
# 3      105.0     9.0               4            7.522         0.03880
# 4       24.0     5.0               5            7.427         0.03553
# ..       ...     ...             ...              ...             ...
# 153    118.0     8.0             154            3.465         0.03464
# 154     13.0     8.0             155            3.340         0.03656
# 155    136.0     4.0             156            3.006         0.05015
# 156     21.0     8.0             157            2.905         0.08658
# 157    141.0     8.0             158            2.839         0.06727
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# ...

# %%
df.skew()
# Out:
# Country                          0.000000
# Region                          -0.116119
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   1.983439
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %% [markdown]
# from  the above data we can observe that the skewness is present in Standard error, family, health, trust and generosity

# %%
df['Standard Error']=np.cbrt(df['Standard Error'])
df.skew()
# Out:
# Country                          0.000000
# Region                          -0.116119
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   0.979748
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %%
df['Standard Error']=np.sqrt(df['Standard Error'])
df.skew()
# Out:
# Country                          0.000000
# Region                          -0.116119
# Happiness Rank                   0.000418
# Happiness Score                  0.097769
# Standard Error                   0.733406
# Economy (GDP per Capita)        -0.317575
# Family                          -1.006893
# Health (Life Expectancy)        -0.705328
# Freedom                         -0.413462
# Trust (Government Corruption)    1.385463
# Generosity                       1.001961
# Dystopia Residual               -0.238911
# dtype: float64

# %%
sns.distplot(df['Standard Error'],color='m',kde_kws={'shade':True},hist=False)
# Out:
# <Axes: xlabel='Standard Error', ylabel='Density'>

# %% [markdown]
# skewness has almot decreased in standard error.

# %%
df.describe()
# Out:
#           Country      Region  Happiness Rank  Happiness Score  \
# count  158.000000  158.000000      158.000000       158.000000
# mean    78.500000    5.120253       79.493671         5.375734
# std     45.754781    2.993321       45.754363         1.145010
# min      0.000000    0.000000        1.000000         2.839000
# 25%     39.250000    3.000000       40.250000         4.526000
# 50%     78.500000    4.500000       79.500000         5.232500
# 75%    117.750000    8.000000      118.750000         6.243750
# max    157.000000    9.000000      158.000000         7.587000
#
#        Standard Error  Economy (GDP per Capita)      Family  \
# count      158.000000                158.000000  158.000000
# mean         0.598212                  0.846137    0.991046
# std          0.031811                  0.403121    0.272369
# min          0.514182                  0.000000    0.000000
# 25%          0.577947                  0.545808    0.856823
# ...

# %%
df.cor=df.corr()
df.cor
# Out:
#                                 Country    Region  Happiness Rank  \
# Country                        1.000000  0.005092       -0.098538
# Region                         0.005092  1.000000        0.213773
# Happiness Rank                -0.098538  0.213773        1.000000
# Happiness Score                0.083380 -0.176791       -0.992105
# Standard Error                 0.023198 -0.055064        0.186760
# Economy (GDP per Capita)       0.037808 -0.260139       -0.785267
# Family                         0.159416 -0.168533       -0.733644
# Health (Life Expectancy)       0.037829 -0.357508       -0.735613
# Freedom                        0.085684  0.092567       -0.556886
# Trust (Government Corruption)  0.088155  0.165040       -0.372315
# Generosity                     0.118085  0.273557       -0.160142
# Dystopia Residual             -0.019778 -0.057276       -0.521999
#
#                                Happiness Score  Standard Error  \
# ...

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(),annot=True,cmap='Blues_r')
# Out:
# <Axes: >

# %%
df.cor['Happiness Score'].sort_values(ascending=False)
# Out:
# Happiness Score                  1.000000
# Economy (GDP per Capita)         0.780966
# Family                           0.740605
# Health (Life Expectancy)         0.724200
# Freedom                          0.568211
# Dystopia Residual                0.530474
# Trust (Government Corruption)    0.395199
# Generosity                       0.180319
# Country                          0.083380
# Region                          -0.176791
# Standard Error                  -0.206371
# Happiness Rank                  -0.992105
# Name: Happiness Score, dtype: float64

# %%
plt.figure(figsize=(22,7))
df.cor['Happiness Score'].sort_values(ascending=False).drop(['Happiness Score']).plot(kind='bar',color='m')
plt.xlabel('Feature',fontsize=10)
plt.ylabel('Target',fontsize=10)
plt.title('Correlation between target and feature')
plt.show()

# %% [markdown]
# Here we can observe that country, Generosity are very much less correlated features with the Happiness score

# %% [markdown]
# seperating features and target

# %%
x=df.drop('Happiness Score',axis=1)
y=df['Happiness Score']

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
x=pd.DataFrame(scaler.fit_transform(x),columns=x.columns)

# %%
x
# Out:
#       Country    Region  Happiness Rank  Standard Error  \
# 0    1.238770  1.300256       -1.721000       -0.906011
# 1   -0.449465  1.300256       -1.699075        0.201217
# 2   -0.909893  1.300256       -1.677149       -0.979595
# 3    0.581016  1.300256       -1.655224       -0.516228
# 4   -1.194920 -0.040302       -1.633299       -0.783512
# ..        ...       ...             ...             ...
# 153  0.866043  0.965117        1.633576       -0.859801
# 154 -1.436096  0.965117        1.655501       -0.697186
# 155  1.260695 -0.375441        1.677427        0.285514
# 156 -1.260695  0.965117        1.699352        2.110162
# 157  1.370321  0.965117        1.721277        1.246251
#
#      Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# 0                    1.369621  1.320281                  1.263408  1.577438
# 1                    1.135226  1.514458                  1.289434  1.332456
# ...

# %%
x.shape
# Out:
# (158, 11)

# %%
y.shape
# Out:
# (158,)

# %%
import sklearn
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import AdaBoostRegressor, GradientBoostingRegressor, RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsRegressor as KNN
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
maxAccu=0
maxRs=0

for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=i)
    lr=LinearRegression()
    lr.fit(x_train,y_train)
    pred=lr.predict(x_test)
    acc=r2_score(y_test,pred)
    if acc>maxAccu:
        maxAccu=acc
        maxRs=i

print("Maximum r2 score is:",maxAccu,"at random_state:",maxRs)
# Out:
# Maximum r2 score is: 0.9999999638029966 at random_state: 148

# %%
DTR=DecisionTreeRegressor()
DTR.fit(x_train,y_train)
pred=DTR.predict(x_test)
pred_train=DTR.predict(x_train)
print('R2_Score:',r2_score(y_test,pred))
print('R2_Score on train data:',r2_score(y_train,pred_train))
print('mean_squared_error:',mean_squared_error(y_test,pred))
print('mean_absolute_error:',mean_absolute_error(y_test,pred))
print('Root mean squared error:',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2_Score: 0.99533804919675
# R2_Score on train data: 1.0
# mean_squared_error: 0.004665729166666661
# mean_absolute_error: 0.04914583333333328
# Root mean squared error: 0.06830614296435322

# %%
RFR=RandomForestRegressor()
RFR.fit(x_train,y_train)
pred=RFR.predict(x_test)
pred_train=RFR.predict(x_train)
print('R2_Score:',r2_score(y_test,pred))
print('R2_Score on train data:',r2_score(y_train,pred_train))
print('mean_squared_error:',mean_squared_error(y_test,pred))
print('mean_absolute_error:',mean_absolute_error(y_test,pred))
print('Root mean squared error:',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2_Score: 0.9948507520398229
# R2_Score on train data: 0.9992526715138739
# mean_squared_error: 0.0051534212624999185
# mean_absolute_error: 0.03478291666666641
# Root mean squared error: 0.07178733357981698

# %%
ABR=AdaBoostRegressor()
ABR.fit(x_train,y_train)
pred=ABR.predict(x_test)
pred_train=ABR.predict(x_train)
print('R2_Score:',r2_score(y_test,pred))
print('R2_Score on train data:',r2_score(y_train,pred_train))
print('mean_squared_error:',mean_squared_error(y_test,pred))
print('mean_absolute_error:',mean_absolute_error(y_test,pred))
print('Root mean squared error:',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2_Score: 0.9950904154366949
# R2_Score on train data: 0.9980557028812483
# mean_squared_error: 0.004913563626038286
# mean_absolute_error: 0.04873116637476166
# Root mean squared error: 0.07009681609059205

# %%
GBR=GradientBoostingRegressor()
GBR.fit(x_train,y_train)
pred=GBR.predict(x_test)
pred_train=GBR.predict(x_train)
print('R2_Score:',r2_score(y_test,pred))
print('R2_Score on train data:',r2_score(y_train,pred_train))
print('mean_squared_error:',mean_squared_error(y_test,pred))
print('mean_absolute_error:',mean_absolute_error(y_test,pred))
print('Root mean squared error:',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2_Score: 0.9978793675730511
# R2_Score on train data: 0.9999982845953702
# mean_squared_error: 0.0021223511323407843
# mean_absolute_error: 0.026820307648974407
# Root mean squared error: 0.046068982323693504

# %%
knn=KNN()
knn.fit(x_train,y_train)
pred=knn.predict(x_test)
pred_train=knn.predict(x_train)
print('R2_Score:',r2_score(y_test,pred))
print('R2_Score on train data:',r2_score(y_train,pred_train))
print('mean_squared_error:',mean_squared_error(y_test,pred))
print('mean_absolute_error:',mean_absolute_error(y_test,pred))
print('Root mean squared error:',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2_Score: 0.9021787510229247
# R2_Score on train data: 0.9321646992426279
# mean_squared_error: 0.09790053000000003
# mean_absolute_error: 0.25171666666666676
# Root mean squared error: 0.3128906038857671

# %%
from sklearn.svm import SVR
svr=SVR()
svr.fit(x_train,y_train)
pred=svr.predict(x_test)
pred_train=svr.predict(x_train)
print('R2_Score:',r2_score(y_test,pred))
print('R2_Score on train data:',r2_score(y_train,pred_train))
print('mean_squared_error:',mean_squared_error(y_test,pred))
print('mean_absolute_error:',mean_absolute_error(y_test,pred))
print('Root mean squared error:',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2_Score: 0.9412038803326206
# R2_Score on train data: 0.9861916640333294
# mean_squared_error: 0.058843772059471895
# mean_absolute_error: 0.16309140233339756
# Root mean squared error: 0.2425773527340751

# %%
Lasso=Lasso()
Lasso.fit(x_train,y_train)
pred=Lasso.predict(x_test)
pred_train=Lasso.predict(x_train)
print('R2_Score:',r2_score(y_test,pred))
print('R2_Score on train data:',r2_score(y_train,pred_train))
print('mean_squared_error:',mean_squared_error(y_test,pred))
print('mean_absolute_error:',mean_absolute_error(y_test,pred))
print('Root mean squared error:',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2_Score: 0.32050888439132896
# R2_Score on train data: 0.3388327346499157
# mean_squared_error: 0.6800418216288565
# mean_absolute_error: 0.6781081103778392
# Root mean squared error: 0.8246464828208852

# %%
Ridge=Ridge()
Ridge.fit(x_train,y_train)
pred=Ridge.predict(x_test)
pred_train=Ridge.predict(x_train)
print('R2_Score:',r2_score(y_test,pred))
print('R2_Score on train data:',r2_score(y_train,pred_train))
print('mean_squared_error:',mean_squared_error(y_test,pred))
print('mean_absolute_error:',mean_absolute_error(y_test,pred))
print('Root mean squared error:',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2_Score: 0.9994753589306652
# R2_Score on train data: 0.9996460958367963
# mean_squared_error: 0.000525066274298805
# mean_absolute_error: 0.016700407055161914
# Root mean squared error: 0.02291432465290664

# %%
from sklearn.ensemble import ExtraTreesRegressor
ETR=DecisionTreeRegressor()
ETR.fit(x_train,y_train)
pred=ETR.predict(x_test)
pred_train=ETR.predict(x_train)
print('R2_Score:',r2_score(y_test,pred))
print('R2_Score on train data:',r2_score(y_train,pred_train))
print('mean_squared_error:',mean_squared_error(y_test,pred))
print('mean_absolute_error:',mean_absolute_error(y_test,pred))
print('Root mean squared error:',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2_Score: 0.9930793589602889
# R2_Score on train data: 1.0
# mean_squared_error: 0.006926249999999994
# mean_absolute_error: 0.06516666666666661
# Root mean squared error: 0.08322409506867584

# %%
from sklearn.model_selection import cross_val_score

# %%
score=cross_val_score(lr,x,y,scoring='r2')
print(score)
print(score.mean())
print("Difference between R2 score and cross validation score is", (r2_score(y_test,pred)-score.mean())*100)
# Out:
# [0.99999949 0.99999846 0.99999828 0.99999564 0.99999935]
# 0.9999982422389339
# Difference between R2 score and cross validation score is -0.6918883278644983

# %%
score=cross_val_score(DTR,x,y,scoring='r2')
print(score)
print(score.mean())
print("Difference between R2 score and cross validation score is", (r2_score(y_test,pred)-score.mean())*100)
# Out:
# [-3.41502425 -0.46010691 -0.39111997 -0.75089806 -2.10524223]
# -1.4244782819117308
# Difference between R2 score and cross validation score is 241.75576408720198

# %%
score=cross_val_score(ABR,x,y,scoring='r2')
print(score)
print(score.mean())
print("Difference between R2 score and cross validation score is", (r2_score(y_test,pred)-score.mean())*100)
# Out:
# [-4.44481706 -1.47217998 -2.07523703 -2.4637415  -2.70850528]
# -2.632896170697344
# Difference between R2 score and cross validation score is 362.59755296576327

# %%
score=cross_val_score(svr,x,y,scoring='r2')
print(score)
print(score.mean())
print("Difference between R2 score and cross validation score is", (r2_score(y_test,pred)-score.mean())*100)
# Out:
# [-12.25150575   0.16164198   0.88905074  -0.46517136  -6.74385683]
# -3.6819682451441595
# Difference between R2 score and cross validation score is 467.5047604104448

# %%
score=cross_val_score(GBR,x,y,scoring='r2')
print(score)
print(score.mean())
print("Difference between R2 score and cross validation score is", (r2_score(y_test,pred)-score.mean())*100)
# Out:
# [-3.00410569 -0.29701699 -0.29113041 -0.37938084 -1.89424829]
# -1.173176443119219
# Difference between R2 score and cross validation score is 216.6255802079508

# %%
score=cross_val_score(ETR,x,y,scoring='r2')
print(score)
print(score.mean())
print("Difference between R2 score and cross validation score is", (r2_score(y_test,pred)-score.mean())*100)
# Out:
# [-3.10920225 -0.45159871 -0.37781244 -0.85979358 -2.10712325]
# -1.3811060455694188
# Difference between R2 score and cross validation score is 237.41854045297077

# %%
score=cross_val_score(Lasso,x,y,scoring='r2')
print(score)
print(score.mean())
print("Difference between R2 score and cross validation score is", (r2_score(y_test,pred)-score.mean())*100)
# Out:
# [-39.5383371   -6.65416738   0.19125992 -17.96627696 -23.65659767]
# -17.524823840209333
# Difference between R2 score and cross validation score is 1851.7903199169623

# %%
score=cross_val_score(Ridge,x,y,scoring='r2')
print(score)
print(score.mean())
print("Difference between R2 score and cross validation score is", (r2_score(y_test,pred)-score.mean())*100)
# Out:
# [0.96477221 0.98525784 0.99409073 0.97704481 0.9876255 ]
# 0.9817582176154822
# Difference between R2 score and cross validation score is 1.1321141344806662

# %% [markdown]
# Ridge is the best model as difference between cross validation score and R2 score is less compared to other models

# %%
from sklearn.model_selection import GridSearchCV
Param={'fit_intercept':[True,False],'positive':[True,False],'copy_X':[True,False],'n_jobs':[1,2,3,4,5]}
GSCV=GridSearchCV(LinearRegression(),Param,cv=5)

# %%
GSCV.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, estimator=LinearRegression(),
#              param_grid={'copy_X': [True, False],
#                          'fit_intercept': [True, False],
#                          'n_jobs': [1, 2, 3, 4, 5], 'positive': [True, False]})

# %%
GSCV.best_params_
# Out:
# {'copy_X': True, 'fit_intercept': True, 'n_jobs': 1, 'positive': False}

# %%
Model=LinearRegression(copy_X=True,fit_intercept=True, n_jobs=1, positive=False)

# %%
Model.fit(x_train,y_train)
pred=Model.predict(x_test)
print('R2_Score:',r2_score(y_test,pred))
print('mean_squared_error:',mean_squared_error(y_test,pred))
print('mean_absolute_error:',mean_absolute_error(y_test,pred))
print('Root mean squared error:',np.sqrt(mean_squared_error(y_test,pred)))
# Out:
# R2_Score: 0.9999999224620714
# mean_squared_error: 7.760077067241478e-08
# mean_absolute_error: 0.00023325637248717648
# Root mean squared error: 0.0002785691488166175

# %%
import pickle
filename='HappinessScore.pkl'
pickle.dump(Model,open(filename,'wb'))

# %%
loaded_model=pickle.load(open('HappinessScore.pkl','rb'))
result=loaded_model.score(x_test,y_test)*100
print(result)
# Out:
# 99.99999224620714

# %%
plt.xlabel('actualScore',fontsize=20)
plt.ylabel('PreditScore',fontsize=20)
plt.plot(y_test,pred,color='blue',marker='+')
plt.show()

# %%
df4=pd.read_csv("https://raw.githubusercontent.com/FlipRoboTechnologies/ML-Datasets/main/Titanic/titanic_train.csv")
df4
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df4.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
df4.tail()
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch      Ticket   Fare Cabin Embarked
# 886    male  27.0      0      0      211536  13.00   NaN        S
# 887  female  19.0      0      0      112053  30.00   B42        S
# 888  female   NaN      1      2  W./C. 6607  23.45   NaN        S
# 889    male  26.0      0      0      111369  30.00  C148        C
# 890    male  32.0      0      0      370376   7.75   NaN        Q

# %%
df4.sample()
# Out:
#      PassengerId  Survived  Pclass                  Name   Sex   Age  SibSp  \
# 122          123         0       2  Nasser, Mr. Nicholas  male  32.5      1
#
#      Parch  Ticket     Fare Cabin Embarked
# 122      0  237736  30.0708   NaN        C

# %%
df4.shape
# Out:
# (891, 12)

# %%
df4.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
df4.index
# Out:
# RangeIndex(start=0, stop=891, step=1)

# %%
df4.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df4.columns.tolist()
# Out:
# ['PassengerId',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %%
df4.isnull()
# Out:
#      PassengerId  Survived  Pclass   Name    Sex    Age  SibSp  Parch  Ticket  \
# 0          False     False   False  False  False  False  False  False   False
# 1          False     False   False  False  False  False  False  False   False
# 2          False     False   False  False  False  False  False  False   False
# 3          False     False   False  False  False  False  False  False   False
# 4          False     False   False  False  False  False  False  False   False
# ..           ...       ...     ...    ...    ...    ...    ...    ...     ...
# 886        False     False   False  False  False  False  False  False   False
# 887        False     False   False  False  False  False  False  False   False
# 888        False     False   False  False  False   True  False  False   False
# 889        False     False   False  False  False  False  False  False   False
# 890        False     False   False  False  False  False  False  False   False
#
#       Fare  Cabin  Embarked
# ...

# %%
df4.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
df4.isnull().sum().sum()
# Out:
# 866

# %% [markdown]
# There are 177 null values in Age and 687 null values in Cabin, 2 in Embarked

# %%
for i in df4.columns:
    print(df4[i].value_counts())
    print("\n")
# Out:
# 1      1
# 599    1
# 588    1
# 589    1
# 590    1
#       ..
# 301    1
# 302    1
# 303    1
# 304    1
# 891    1
# Name: PassengerId, Length: 891, dtype: int64
#
#
# 0    549
# 1    342
# Name: Survived, dtype: int64
#
#
# 3    491
# 1    216
# 2    184
# Name: Pclass, dtype: int64
#
#
# Braund, Mr. Owen Harris                     1
# Boulos, Mr. Hanna                           1
# Frolicher-Stehli, Mr. Maxmillian            1
# Gilinski, Mr. Eliezer                       1
# Murdlin, Mr. Joseph                         1
#                                            ..
# Kelly, Miss. Anna Katherine "Annie Kate"    1
# McCoy, Mr. Bernard                          1
# Johnson, Mr. William Cahoone Jr             1
# Keane, Miss. Nora A                         1
# Dooley, Mr. Patrick                         1
# Name: Name, Length: 891, dtype: int64
#
#
# male      577
# female    314
# Name: Sex, dtype: int64
#
#
# 24.00    30
# 22.00    27
# 18.00    26
# 19.00    25
# 28.00    25
# ...

# %%
a=sns.countplot(x='Sex',data=df4)
plt.show()

# %%
a=sns.countplot(x='Survived',data=df4)
plt.show()

# %%
a=sns.countplot(x='Pclass',data=df4)
plt.show()

# %%
a=sns.countplot(x='SibSp',data=df4)
plt.show()

# %%
a=sns.countplot(x='Parch',data=df4)
plt.show()

# %%
a=sns.countplot(x='Embarked',data=df4)
plt.show()

# %%
np.mean(df4['Survived'])
# Out:
# 0.3838383838383838

# %%
df4['Survived']=df4['Survived'].fillna(df4['Survived'].mean())

# %%
df4.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
np.mean(df4['Age'])
# Out:
# 29.69911764705882

# %%
df4['Age']=df4['Age'].fillna(df4['Age'].mean())

# %%
df4.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
sns.heatmap(df4.isnull())
# Out:
# <Axes: >

# %%
categorical_col=[]

for i in df4.dtypes.index:
    if df4.dtypes[i]=='object':
        categorical_col.append(i)
print('Categorical col=',categorical_col)

numerical_col=[]

for i in df4.dtypes.index:
    if df4.dtypes[i]!='object':
        numerical_col.append(i)
print('Numerical col=',numerical_col)
# Out:
# Categorical col= ['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked']
# Numerical col= ['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare']

# %%
df4.nunique().to_frame("No.of.unique values")
# Out:
#              No.of.unique values
# PassengerId                  891
# Survived                       2
# Pclass                         3
# Name                         891
# Sex                            2
# Age                           89
# SibSp                          7
# Parch                          7
# Ticket                       681
# Fare                         248
# Cabin                        147
# Embarked                       3

# %%
df4.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  891.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   13.002015    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   22.000000    0.000000
# 50%     446.000000    0.000000    3.000000   29.699118    0.000000
# 75%     668.500000    1.000000    3.000000   35.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200
